# %%
# %pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 96.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 79.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, safetensors, xxhash, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.13.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.15.1 multidict-6.0.4 multiprocess-0.70.14 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2 xxhash-3.2.0 yarl-1.9.2

# %%
from datasets import load_dataset

import torch
import torch.nn as nn
import torch.nn.functional as F

from typing import Dict, List

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# *Basic Model, definition and loaded*

# %%
from tqdm.auto import tqdm
from collections import defaultdict
import pickle


class Morph():

    """ Trainable class that goes through a corpus and first saves the
        available words in a dictionary. It then reiterates the corpus and
        saves endings of the corpus by checking if each subword exists in the
        corpus. """

    def __init__(self):
        self.counts = defaultdict(lambda: 0)
        self.endings = defaultdict(lambda: 0)

        self.probable_endings = []
        self.is_trained = False

        self.vocab = set()

    def train(self, vocab):
        """ Training function.

            param: vocab: func -> generator

            Takes a function that returns a generator which is used twice in
            order to first create the counts dictionary, and then the
            endings-dictionary
        """
        v, l = vocab()
        bar = tqdm(range(l))
        for d in v:
            for sen in d:
                for word in sen.split():
                    word = word.lower()
                    self.vocab.add(word)
                    self.counts[word] += 1
            bar.update()

        v, l = vocab()
        bar = tqdm(range(l))
        for d in v:
            for sen in d:
                for word in sen.split():
                    word = word.lower()
                    self.process_word(word)
            bar.update()

        self.is_trained = True
        self.num_tokens = len(self.vocab)

    def process_word(self, word):
        """ Processes an input word.

            param: word: str

            Take and looks at each subword. Adds the ending to the
            endings-dictionary if the stem exits in the vocab. """

        stem = ''
        scores = {}

        for char in word.lower():
            stem += char
            ending = word[len(stem):]
            if self.counts[stem] and ending != '':
                self.endings[ending] += 1

    def evaluate_word(self, word):
        stem = ''
        endscores = {}
        scores = {}

        # Get counts
        for char in word.lower():
            stem += char
            ending = word[len(stem):]
            scores[stem] = self.counts[stem]
            endscores[ending] = self.endings[ending]

        print(scores)
        print(endscores)

        # Normalize
        sum_stem = 0
        sum_end = 0
        for score, endscore in zip(scores.values(), endscores.values()):
          sum_end += endscore
          sum_stem += score

        if sum_stem:
          stemprobs = {key: value / sum_stem  for key, value in scores.items()}
        else:
          stemprobs = {key: value for key, value in scores.items()}

        if sum_end:
          endprobs = {key: value / sum_end  for key, value in endscores.items()}
        else:
          endprobs = {key: value for key, value in endscores.items()}

        if not sum_end and not sum_stem:
          return (word, '')

        #print(stemprobs)

        highest_split = 0
        stem = ''
        pair = (word, '')
        total_prob = 0
        for char in word:
            stem += char
            ending = word[len(stem):]

            if stemprobs[stem]: # Only include splits were stem is in the vocab
              prob = ((1 * stemprobs[stem]) + (1 * endprobs[ending])) / 2
              total_prob += prob
            else:
              prob = 0
              total_prob += prob

            if highest_split < prob:
                highest_split = prob
                pair = (stem, ending)

        return pair

    def evaluate_sentence(self, sentence):
        tokens = sentence.split()
        splits = [ self.evaluate_word(word.lower()) for word in tokens ]

        processed_sentence = ""
        for split in splits:

            stem = split[0]
            end = split[1]

            word = stem

            if end != '' and stem != '':
                word = stem + '-' + end
            elif word != '' and end == '':
                word = stem
            else:
                word = end

            processed_sentence += word + ' '

        return processed_sentence

    def get_probable_endings(self, n=20):
        e, p = list(self.endings.keys()), list(self.endings.values())

        a = [x for _, x in sorted(zip(p, e))]

        self.probable_endings = a[-n:]
        return self.probable_endings

    def get_endings(self):
        if self.is_trained:
            return self.probable_endings
        else:
            print("Model has not been trained. ")
            return False

    def load_model(self, path, drive=False):
        if drive:
            file_path = '/content/gdrive/MyDrive/' + path
        else:
            file_path = path

        with open(file_path + '_counts.pickle', 'rb') as handle:
            self.counts = pickle.load(handle)

        with open(file_path + '_endings.pickle', 'rb') as handle:
            self.endings = pickle.load(handle)

        self.counts = defaultdict(int, self.counts)
        self.endings = defaultdict(int, self.endings)

        self.is_trained = True
        self.get_probable_endings()

        self.vocab = set(list(self.counts.keys()))
        self.num_tokens = len(self.vocab)

        return True

    def save_model(self, path, drive=False):
        if drive:
            file_path = '/content/gdrive/MyDrive/' + path
        else:
            file_path = path

        with open(file_path + '_counts.pickle', 'wb') as handle:
            pickle.dump(dict(self.counts), handle, protocol=pickle.HIGHEST_PROTOCOL)

        with open(file_path + '_endings.pickle', 'wb') as handle:
            pickle.dump(dict(self.endings), handle, protocol=pickle.HIGHEST_PROTOCOL)

        return True

    def __call__(self, sentence):
        return self.evaluate_sentence(sentence)

m = Morph()

# %%
m.load_model('swedish_model', drive=True)
# Out:
# True

# %% [markdown]
# *Evaluate the basic model*

# %%
m("barnen stabilt ditt sked? badkar spelad skedar spelat")
# Out:
# {'b': 4, 'ba': 1, 'bar': 1, 'barn': 16, 'barne': 0, 'barnen': 0}
# {'arnen': 0, 'rnen': 0, 'nen': 8, 'en': 811, 'n': 2639, '': 0}
# {'s': 9, 'st': 3, 'sta': 0, 'stab': 0, 'stabi': 0, 'stabil': 0, 'stabilt': 0}
# {'tabilt': 0, 'abilt': 0, 'bilt': 0, 'ilt': 0, 'lt': 12, 't': 2270, '': 0}
# {'d': 0, 'di': 0, 'dit': 0, 'ditt': 63}
# {'itt': 131, 'tt': 2283, 't': 2270, '': 0}
# {'s': 9, 'sk': 0, 'ske': 0, 'sked': 0, 'sked?': 0}
# {'ked?': 0, 'ed?': 9, 'd?': 43, '?': 4278, '': 0}
# {'b': 4, 'ba': 1, 'bad': 4, 'badk': 0, 'badka': 0, 'badkar': 0}
# {'adkar': 0, 'dkar': 0, 'kar': 7, 'ar': 527, 'r': 1785, '': 0}
# {'s': 9, 'sp': 0, 'spe': 0, 'spel': 9, 'spela': 12, 'spelad': 0}
# {'pelad': 0, 'elad': 0, 'lad': 0, 'ad': 1415, 'd': 158, '': 0}
# {'s': 9, 'sk': 0, 'ske': 0, 'sked': 0, 'skeda': 0, 'skedar': 0}
# {'kedar': 0, 'edar': 0, 'dar': 4, 'ar': 527, 'r': 1785, '': 0}
# {'s': 9, 'sp': 0, 'spe': 0, 'spel': 9, 'spela': 12, 'spelat': 1}
# {'pelat': 1, 'elat': 0, 'lat': 0, 'at': 36, 't': 2270, '': 0}
# 'barn-en s-tabilt ditt s-ked? bad-kar spel-ad s-kedar spela-t '

# %%
m.get_probable_endings(n=10)
# Out:
# ['ör', 'an', 'ad', 'r', 'g', 't', 'tt', 'n', 'a', '?']

# %% [markdown]
# *Preparing Data Generators for Training of Basic Model, don't run unless you want to train new model*

# %%
### English data
data = load_dataset('xsum')

def get_vocab():
    le = 1000
    batch_size = 10
    return ([data['train']['document'][i] for i in range(batch_size)] for _ in range(le)), le
# Out:
# WARNING:datasets.builder:Found cached dataset xsum (/root/.cache/huggingface/datasets/xsum/default/1.2.0/082863bf4754ee058a5b6f6525d0cb2b18eadb62c7b370b095d1364050a52b71)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
### Swedish data
sv = load_dataset('KBLab/overlim', 'qqp_sv')

def get_vocab():
    le = 300000
    batch_size = 50
    return (sv['train']['text_a'][i*batch_size:(i + 1)*batch_size] for i in range(0, le, batch_size)), int(le / batch_size)
# Out:
# Downloading builder script:   0%|          | 0.00/22.2k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/98.0k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/3.26k [00:00<?, ?B/s]
# Downloading and preparing dataset overlim/qqp_sv (download: 20.98 MiB, generated: 55.33 MiB, post-processed: Unknown size, total: 76.31 MiB) to /root/.cache/huggingface/datasets/KBLab___overlim/qqp_sv/1.0.2/6ca5c4db42719c22d2dfbc40ce443cc3ffe94db893063ec66686be25549c7e7b...
# Downloading data:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/323419 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/40427 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/40430 [00:00<?, ? examples/s]
# Dataset overlim downloaded and prepared to /root/.cache/huggingface/datasets/KBLab___overlim/qqp_sv/1.0.2/6ca5c4db42719c22d2dfbc40ce443cc3ffe94db893063ec66686be25549c7e7b. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# *Prepare for semi-supervised learning by picking out labels based on the basic model*

# %%
def get_gold_labels(model):
    e, p = list(model.endings.keys()), list(model.endings.values())

    a = [x for _, x in sorted(zip(p, e))]
    end = a[-30:] # Only picking words with most common endings

    print(end)

    gold = {}
    for word in list(model.vocab):
        if model.counts[word] < 0.001*model.num_tokens: # Hyperparameter

            pair = model.evaluate_word(word)
            ending = pair[1]

            if ending in end or ending == '':
              gold[word] = ending

    return gold

labeled_data = get_gold_labels(m)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'l': 1, 'lå': 0, 'låt': 7, 'låts': 0, 'låtsa': 0, 'låtsas': 2, 'låtsasv': 0, 'låtsasvä': 0, 'låtsasvän': 0, 'låtsasvänn': 0, 'låtsasvänne': 0, 'låtsasvänner': 0, 'låtsasvänner?': 1}
# {'åtsasvänner?': 1, 'tsasvänner?': 0, 'sasvänner?': 1, 'asvänner?': 0, 'svänner?': 0, 'vänner?': 1, 'änner?': 5, 'nner?': 1, 'ner?': 8, 'er?': 118, 'r?': 74, '?': 4278, '': 0}
# {'b': 4, 'br': 1, 'bro': 0, 'bror': 4, 'brors': 1, 'brorso': 0}
# {'rorso': 0, 'orso': 0, 'rso': 0, 'so': 1, 'o': 72, '': 0}
# {'i': 1572, 'im': 1, 'imi': 0, 'imin': 0, 'imino': 0, 'iminod': 0, 'iminodi': 0, 'iminodiä': 0, 'iminodiät': 0, 'iminodiätt': 0, 'iminodiätti': 0, 'iminodiättik': 0, 'iminodiättiks': 0, 'iminodiättiksy': 0, 'iminodiättiksyr': 0, 'iminodiättiksyra': 0}
# {'minodiättiksyra': 0, 'inodiättiksyra': 0, 'nodiättiksyra': 0, 'odiättiksyra': 0, 'diättiksyra': 0, 'iättiksyra': 0, 'ättiksyra': 0, 'ttiksyra': 0, 'tiksyra': 0, 'iksyra': 0, 'ksyra': 0, 'syra': 0, 'yra': 10, 'ra': 320, 'a': 2904, '': 0}
# {'j': 0, 'jo': 0, 'jor': 0, 'jord': 2, 'jordt': 0}
# {'ordt': 0, 'rdt': 0, 'dt': 0, 't': 2270, '': 0}
# {'f': 2, 'fö': 0, 'för': 1109, 'före': 19, 'föret': 0, 'företa': 0, 'företag': 28, 'företage': 0, 'företaget': 3, 'företaget?': 1}
# {'öretaget?': 1, 'retaget?': 0, 'etaget?': 1, 'taget?': 2, 'aget?': 1, 'get?': 2, 'et?': 131, 't?': 227, '?': 4278, '': 0}
# {'a': 3, 'av': 577, 'avg': 1, 'avgå': 0, 'avgår': 0}
# {'vgår': 0, 'går': 6, 'år': 188, 'r': 1785, '': 0}
# {'p': 0, 'pa': 2, 'pat': 0, 'pate': 0, 'paten': 0, 'patent': 0, 'patenta': 0, 'patentan': 0}
# {'atentan': 0, 'tentan': 0, 'entan': 0, 'ntan': 0, 'tan': 0, 'an': 1355, 'n': 2639, '': 0}
# {'u': 0, 'ut': 58, 'utg': 0, 'utgå': 0, 'utgån': 0, 'utgång': 0, 'utgångs': 0, 'utgångsp': 0, 'utgångspu': 0, 'utgångspun': 0, 'utgångspunk': 0}
# {'tgångspunk': 0, 'gångspunk': 0, 'ångspunk': 0, 'ngspunk': 0, 'gspunk': 0, 'spunk': 0, 'punk': 0, 'unk': 0, 'nk': 7, 'k': 41, '': 0}
# {'a': 3, 'as': 0, 'asi': 0, 'asim': 0, 'asimo': 0, 'asimov': 0}
# {'simov': 0, 'imov': 0, 'mov': 0, 'ov': 4, 'v': 613, '': 0}
# {'j': 0, 'ja': 2, 'jai': 0, 'jain': 0, 'jaini': 0, 'jainis': 0}
# {'ainis': 0, 'inis': 0, 'nis': 0, 'is': 8, 's': 656, '': 0}
# {'d': 0, 'du': 621, 'dub': 0, 'dubb': 0, 'dubbe': 0, 'dubbel': 1, 'dubbels': 0, 'dubbelsl': 0, 'dubbelsli': 0, 'dubbelslit': 0, 'dubbelslite': 0, 'dubbelslitet': 1}
# {'ubbelslitet': 0, 'bbelslitet': 1, 'belslitet': 0, 'elslitet': 0, 'lslitet': 0, 'slitet': 1, 'litet': 0, 'itet': 7, 'tet': 0, 'et': 413, 't': 2270, '': 0}
# {'h': 0, 'ha': 116, 'har': 448, 'harr': 0, 'harri': 0}
# {'arri': 0, 'rri': 0, 'ri': 4, 'i': 192, '': 0}
# {'a': 3, 'au': 0, 'auk': 0, 'aukt': 0, 'aukto': 0, 'auktor': 0, 'auktori': 0, 'auktoris': 0, 'auktorise': 0}
# {'uktorise': 0, 'ktorise': 0, 'torise': 0, 'orise': 0, 'rise': 0, 'ise': 0, 'se': 10, 'e': 489, '': 0}
# {'g': 4, 'go': 4, 'gol': 0, 'gold': 1, 'golde': 0}
# {'olde': 0, 'lde': 0, 'de': 196, 'e': 489, '': 0}
# {'b': 4, 'ba': 1, 'bat': 0, 'batm': 0, 'batma': 0, 'batman': 3, 'batman-': 0, 'batman-f': 0, 'batman-fö': 0, 'batman-för': 0, 'batman-före': 0, 'batman-föres': 0, 'batman-förest': 0, 'batman-förestä': 0, 'batman-förestäl': 0, 'batman-föreställ': 0, 'batman-föreställn': 0}
# {'atman-föreställn': 0, 'tman-föreställn': 0, 'man-föreställn': 0, 'an-föreställn': 0, 'n-föreställn': 0, '-föreställn': 0, 'föreställn': 0, 'öreställn': 0, 'reställn': 0, 'eställn': 0, 'ställn': 0, 'tälln': 0, 'älln': 0, 'lln': 0, 'ln': 0, 'n': 2639, '': 0}
# {'v': 2, 'va': 0, 'val': 4, 'valn': 0}
# {'aln': 0, 'ln': 0, 'n': 2639, '': 0}
# {'s': 9, 'st': 3, 'str': 0, 'strö': 0, 'ström': 2, 'strömb': 0, 'strömbr': 0}
# {'trömbr': 0, 'römbr': 0, 'ömbr': 0, 'mbr': 0, 'br': 0, 'r': 1785, '': 0}
# {'l': 1, 'lå': 0, 'lån': 3, 'lång': 28, 'långd': 0, 'långdi': 0, 'långdis': 0, 'långdist': 0, 'långdista': 0, 'långdistan': 0, 'långdistans': 1, 'långdistansf': 0, 'långdistansfö': 0, 'långdistansför': 0, 'långdistansförh': 0, 'långdistansförhå': 0, 'långdistansförhål': 0, 'långdistansförhåll': 0, 'långdistansförhålla': 0, 'långdistansförhållan': 0, 'långdistansförhålland': 0, 'långdistansförhållande': 0}
# {'ångdistansförhållande': 0, 'ngdistansförhållande': 0, 'gdistansförhållande': 0, 'distansförhållande': 0, 'istansförhållande': 0, 'stansförhållande': 0, 'tansförhållande': 0, 'ansförhållande': 0, 'nsförhållande': 0, 'sförhållande': 1, 'förhållande': 0, 'örhållande': 7, 'rhållande': 0, 'hållande': 7, 'ållande': 0, 'llande': 0, 'lande': 1, 'ande': 12, 'nde': 70, 'de': 196, 'e': 489, '': 0}
# {'b': 4, 'b.': 0, 'b.e': 0}
# {'.e': 0, 'e': 489, '': 0}
# {'k': 1, 'ku': 0, 'kui': 0, 'kuip': 0}
# {'uip': 0, 'ip': 2, 'p': 19, '': 0}
# {'s': 9, 'sp': 0, 'spr': 0, 'sprä': 0, 'sprän': 0, 'spräng': 0}
# {'präng': 0, 'räng': 0, 'äng': 17, 'ng': 14, 'g': 1974, '': 0}
# {'a': 3, 'ac': 2, 'ack': 0, 'acku': 0, 'ackum': 0, 'ackumu': 0, 'ackumul': 0, 'ackumule': 0, 'ackumuler': 0, 'ackumuleri': 0, 'ackumulerin': 0}
# {'ckumulerin': 0, 'kumulerin': 0, 'umulerin': 0, 'mulerin': 0, 'ulerin': 0, 'lerin': 0, 'erin': 0, 'rin': 0, 'in': 434, 'n': 2639, '': 0}
# {'w': 3, 'wa': 0, 'war': 0}
# {'ar': 527, 'r': 1785, '': 0}
# {'b': 4, 'bi': 2, 'bil': 11, 'bill': 3, 'billi': 0, 'billig': 2, 'billiga': 6, 'billigar': 0, 'billigare': 2}
# {'illigare': 2, 'lligare': 2, 'ligare': 3, 'igare': 16, 'gare': 1, 'are': 66, 're': 112, 'e': 489, '': 0}
# {'"': 2, '"m': 0, '"mä': 0, '"män': 0, '"männ': 0, '"männi': 0, '"männis': 0, '"människ': 0}
# {'människ': 0, 'ännisk': 0, 'nnisk': 0, 'nisk': 2, 'isk': 33, 'sk': 24, 'k': 41, '': 0}
# {'m': 1, 'mo': 0, 'mot': 69, 'moto': 4, 'motor': 1, 'motore': 0}
# {'otore': 0, 'tore': 2, 'ore': 5, 're': 112, 'e': 489, '': 0}
# {'c': 2, 'ce': 0, 'cel': 0, 'cell': 2, 'cellu': 0, 'cellul': 0}
# {'ellul': 0, 'llul': 0, 'lul': 0, 'ul': 1, 'l': 470, '': 0}
# {'l': 1, 'lo': 0, 'loc': 0, 'lock': 0, 'locka': 1}
# {'ocka': 2, 'cka': 15, 'ka': 266, 'a': 2904, '': 0}
# {'e': 11, 'eg': 0, 'ege': 0, 'egen': 16, 'egens': 0, 'egensk': 0, 'egenska': 0}
# {'genska': 0, 'enska': 0, 'nska': 34, 'ska': 68, 'ka': 266, 'a': 2904, '': 0}
# {'v': 2, 'vå': 0, 'våg': 0, 'vågl': 0, 'våglä': 0}
# {'åglä': 0, 'glä': 0, 'lä': 0, 'ä': 0, '': 0}
# {'l': 1, 'lo': 0, 'log': 0, 'logg': 0, 'loggn': 0, 'loggni': 0, 'loggnin': 0, 'loggning': 1}
# {'oggning': 1, 'ggning': 0, 'gning': 2, 'ning': 14, 'ing': 13, 'ng': 14, 'g': 1974, '': 0}
# {'a': 3, 'an': 0, 'ans': 0, 'anst': 0, 'ansti': 0, 'anstif': 0, 'anstift': 0}
# {'nstift': 0, 'stift': 0, 'tift': 0, 'ift': 3, 'ft': 11, 't': 2270, '': 0}
# {'[': 0, '[m': 0, '[ma': 0, '[mat': 0, '[math': 0, '[math]': 1, '[math]b': 0, '[math]b^': 0, '[math]b^3': 0, '[math]b^3+': 0, '[math]b^3+a': 0, '[math]b^3+ac': 0, '[math]b^3+ac^': 0, '[math]b^3+ac^2': 0, '[math]b^3+ac^2+': 0, '[math]b^3+ac^2+a': 0, '[math]b^3+ac^2+a^': 0, '[math]b^3+ac^2+a^2': 0, '[math]b^3+ac^2+a^2c': 0, '[math]b^3+ac^2+a^2c[': 0, '[math]b^3+ac^2+a^2c[/': 0}
# {'math]b^3+ac^2+a^2c[/': 0, 'ath]b^3+ac^2+a^2c[/': 0, 'th]b^3+ac^2+a^2c[/': 0, 'h]b^3+ac^2+a^2c[/': 0, ']b^3+ac^2+a^2c[/': 0, 'b^3+ac^2+a^2c[/': 0, '^3+ac^2+a^2c[/': 0, '3+ac^2+a^2c[/': 0, '+ac^2+a^2c[/': 0, 'ac^2+a^2c[/': 0, 'c^2+a^2c[/': 0, '^2+a^2c[/': 0, '2+a^2c[/': 0, '+a^2c[/': 0, 'a^2c[/': 0, '^2c[/': 0, '2c[/': 0, 'c[/': 0, '[/': 0, '/': 2, '': 0}
# {'b': 4, 'bö': 0, 'bör': 74, 'börs': 0, 'börsa': 0, 'börsap': 0, 'börsapp': 0}
# {'örsapp': 0, 'rsapp': 0, 'sapp': 0, 'app': 2, 'pp': 11, 'p': 19, '': 0}
# {'t': 2, 'ti': 0, 'til': 1, 'till': 394, 'tillg': 0, 'tillgä': 0, 'tillgän': 0, 'tillgäng': 0, 'tillgängl': 0, 'tillgängli': 0, 'tillgänglig': 0, 'tillgängliga': 5}
# {'illgängliga': 5, 'llgängliga': 0, 'lgängliga': 5, 'gängliga': 5, 'ängliga': 0, 'ngliga': 0, 'gliga': 8, 'liga': 75, 'iga': 27, 'ga': 15, 'a': 2904, '': 0}
# {'d': 0, 'da': 1, 'dat': 0, 'dato': 0, 'dator': 11, 'datorp': 0, 'datorpr': 0, 'datorpro': 0, 'datorprog': 0, 'datorprogr': 0, 'datorprogra': 0, 'datorprogram': 0, 'datorprogram?': 1}
# {'atorprogram?': 0, 'torprogram?': 1, 'orprogram?': 0, 'rprogram?': 0, 'program?': 7, 'rogram?': 0, 'ogram?': 3, 'gram?': 3, 'ram?': 0, 'am?': 10, 'm?': 35, '?': 4278, '': 0}
# {'t': 2, 'tv': 10, 'tv-': 0, 'tv-a': 0, 'tv-ap': 0, 'tv-app': 0}
# {'v-app': 0, '-app': 0, 'app': 2, 'pp': 11, 'p': 19, '': 0}
# {'b': 4, 'bi': 2, 'bio': 0, 'bioo': 0}
# {'ioo': 0, 'oo': 0, 'o': 72, '': 0}
# {'m': 1, 'må': 2, 'mås': 0, 'måst': 0, 'måste': 27}
# {'åste': 27, 'ste': 132, 'te': 317, 'e': 489, '': 0}
# {'j': 0, 'ju': 0, 'jun': 0, 'juni': 0, 'junio': 0, 'junior': 0}
# {'unior': 0, 'nior': 1, 'ior': 1, 'or': 34, 'r': 1785, '': 0}
# {'x': 8, 'x-': 0, 'x-r': 0}
# {'-r': 0, 'r': 1785, '': 0}
# {'s': 9, 'si': 0, 'sid': 0, 'sidn': 0, 'sidnu': 0, 'sidnum': 0, 'sidnumr': 0, 'sidnumre': 0}
# {'idnumre': 0, 'dnumre': 0, 'numre': 0, 'umre': 0, 'mre': 0, 're': 112, 'e': 489, '': 0}
# {'h': 0, 'he': 0, 'hed': 0, 'hedg': 0, 'hedge': 0, 'hedgef': 0, 'hedgefo': 0, 'hedgefon': 0, 'hedgefond': 1}
# {'edgefond': 0, 'dgefond': 0, 'gefond': 0, 'efond': 0, 'fond': 0, 'ond': 1, 'nd': 27, 'd': 158, '': 0}
# {'s': 9, 'sk': 0, 'ski': 0, 'skil': 0, 'skilj': 0, 'skilja': 3, 'skilja?': 1}
# {'kilja?': 1, 'ilja?': 0, 'lja?': 0, 'ja?': 9, 'a?': 195, '?': 4278, '': 0}
# {'g': 4, 'gr': 1, 'gre': 4, 'gre-': 0, 'gre-f': 0, 'gre-fö': 0, 'gre-för': 0, 'gre-förb': 0, 'gre-förbe': 0, 'gre-förber': 0, 'gre-förbere': 0, 'gre-förbered': 0, 'gre-förberede': 0, 'gre-förberedel': 0, 'gre-förberedels': 0, 'gre-förberedelse': 0, 'gre-förberedelser': 0, 'gre-förberedelser?': 1}
# {'re-förberedelser?': 1, 'e-förberedelser?': 1, '-förberedelser?': 1, 'förberedelser?': 0, 'örberedelser?': 0, 'rberedelser?': 0, 'beredelser?': 0, 'eredelser?': 0, 'redelser?': 0, 'edelser?': 0, 'delser?': 0, 'elser?': 0, 'lser?': 0, 'ser?': 2, 'er?': 118, 'r?': 74, '?': 4278, '': 0}
# {'e': 11, 'en': 1359, 'eng': 0, 'enge': 0, 'engel': 0, 'engels': 0}
# {'ngels': 0, 'gels': 0, 'els': 1, 'ls': 7, 's': 656, '': 0}
# {'b': 4, 'be': 1, 'ben': 3, 'bent': 0, 'bentr': 0, 'benträ': 0, 'benträn': 0, 'benträni': 0, 'bentränin': 0}
# {'entränin': 0, 'ntränin': 0, 'tränin': 0, 'ränin': 0, 'änin': 0, 'nin': 0, 'in': 434, 'n': 2639, '': 0}
# {'r': 4, 're': 0, 'rek': 0, 'reko': 0, 'rekom': 0, 'rekomm': 0, 'rekomme': 0, 'rekommen': 0, 'rekommend': 0, 'rekommenda': 0, 'rekommendat': 0, 'rekommendati': 0, 'rekommendatio': 0, 'rekommendation': 0, 'rekommendatione': 0, 'rekommendationer': 1}
# {'ekommendationer': 1, 'kommendationer': 0, 'ommendationer': 0, 'mmendationer': 0, 'mendationer': 0, 'endationer': 0, 'ndationer': 0, 'dationer': 0, 'ationer': 0, 'tioner': 1, 'ioner': 2, 'oner': 3, 'ner': 41, 'er': 769, 'r': 1785, '': 0}
# {'h': 0, 'hå': 0, 'hår': 6, 'hårv': 0}
# {'årv': 0, 'rv': 1, 'v': 613, '': 0}
# {'s': 9, 'se': 40, 'sek': 0, 'sekt': 0, 'sekti': 0}
# {'ekti': 0, 'kti': 0, 'ti': 6, 'i': 192, '': 0}
# {'s': 9, 'su': 0, 'sup': 0, 'supp': 0, 'suppo': 0, 'suppor': 0, 'support': 2, 'supporti': 0, 'supportin': 0, 'supporting': 0, 'supportinge': 0, 'supportingen': 0, 'supportingenj': 0, 'supportingenjö': 0, 'supportingenjör': 0, 'supportingenjöre': 0, 'supportingenjörer': 0}
# {'upportingenjörer': 0, 'pportingenjörer': 0, 'portingenjörer': 0, 'ortingenjörer': 0, 'rtingenjörer': 0, 'tingenjörer': 0, 'ingenjörer': 1, 'ngenjörer': 1, 'genjörer': 1, 'enjörer': 0, 'njörer': 0, 'jörer': 1, 'örer': 1, 'rer': 2, 'er': 769, 'r': 1785, '': 0}
# {'v': 2, 'vi': 150, 'vik': 0, 'vikt': 29, 'vikto': 0}
# {'ikto': 0, 'kto': 0, 'to': 9, 'o': 72, '': 0}
# {'c': 2, 'ch': 0, 'cho': 0, 'chon': 0, 'chong': 0, 'chongq': 0, 'chongqi': 0, 'chongqin': 0, 'chongqing': 0, 'chongqing,': 1}
# {'hongqing,': 1, 'ongqing,': 0, 'ngqing,': 0, 'gqing,': 0, 'qing,': 0, 'ing,': 0, 'ng,': 0, 'g,': 8, ',': 410, '': 0}
# {'a': 3, 'as': 0, 'ask': 0, 'ask-': 0, 'ask-t': 0, 'ask-to': 0, 'ask-to-': 0, 'ask-to-a': 0, 'ask-to-an': 0, 'ask-to-ans': 0, 'ask-to-answ': 0, 'ask-to-answe': 0, 'ask-to-answer': 1}
# {'sk-to-answer': 1, 'k-to-answer': 0, '-to-answer': 0, 'to-answer': 0, 'o-answer': 0, '-answer': 0, 'answer': 0, 'nswer': 0, 'swer': 0, 'wer': 3, 'er': 769, 'r': 1785, '': 0}
# {'d': 0, 'di': 0, 'dis': 0, 'disk': 0, 'diskv': 0, 'diskva': 0, 'diskval': 0, 'diskvali': 0, 'diskvalif': 0}
# {'iskvalif': 0, 'skvalif': 0, 'kvalif': 0, 'valif': 0, 'alif': 0, 'lif': 0, 'if': 0, 'f': 0, '': 0}
# {'n': 3, 'ni': 13, 'nik': 0, 'niko': 0, 'nikol': 0, 'nikola': 2}
# {'ikola': 2, 'kola': 3, 'ola': 1, 'la': 114, 'a': 2904, '': 0}
# {'a': 3, 'ap': 0, 'app': 8, 'appu': 0, 'apput': 0}
# {'pput': 0, 'put': 0, 'ut': 2, 't': 2270, '': 0}
# {'s': 9, 'sh': 0, 'she': 0, 'shep': 0, 'sheph': 0, 'shephe': 0, 'shepher': 0, 'shepherd': 1, 'shepherd/': 0, 'shepherd/b': 0, 'shepherd/bo': 0, 'shepherd/bor': 0, 'shepherd/bord': 0}
# {'hepherd/bord': 0, 'epherd/bord': 0, 'pherd/bord': 0, 'herd/bord': 0, 'erd/bord': 0, 'rd/bord': 0, 'd/bord': 0, '/bord': 0, 'bord': 1, 'ord': 11, 'rd': 4, 'd': 158, '': 0}
# {'j': 0, 'jq': 0, 'jqu': 0, 'jque': 0}
# {'que': 0, 'ue': 0, 'e': 489, '': 0}
# {'e': 11, 'et': 1, 'eta': 0}
# {'ta': 134, 'a': 2904, '': 0}
# {'a': 3, 'al': 1, 'alz': 0, 'alzh': 0, 'alzhe': 0, 'alzhei': 0, 'alzheim': 0}
# {'lzheim': 0, 'zheim': 0, 'heim': 0, 'eim': 0, 'im': 14, 'm': 67, '': 0}
# {'u': 0, 'ut': 58, 'utv': 0, 'utve': 0, 'utvec': 0, 'utveck': 0, 'utveckl': 0, 'utveckli': 0, 'utvecklin': 0, 'utveckling': 2, 'utvecklings': 0, 'utvecklingss': 0, 'utvecklingsst': 0, 'utvecklingsstu': 0, 'utvecklingsstud': 0}
# {'tvecklingsstud': 0, 'vecklingsstud': 0, 'ecklingsstud': 0, 'cklingsstud': 0, 'klingsstud': 0, 'lingsstud': 0, 'ingsstud': 0, 'ngsstud': 0, 'gsstud': 0, 'sstud': 0, 'stud': 0, 'tud': 0, 'ud': 12, 'd': 158, '': 0}
# {'i': 1572, 'is': 1, 'isl': 0, 'isli': 0, 'islin': 0, 'isling': 0, 'islingt': 0, 'islingto': 0, 'islington': 0, 'islington?': 1}
# {'slington?': 1, 'lington?': 1, 'ington?': 0, 'ngton?': 0, 'gton?': 0, 'ton?': 0, 'on?': 2, 'n?': 112, '?': 4278, '': 0}
# {'b': 4, 'bl': 0, 'bli': 120, 'bliv': 0, 'blivi': 0}
# {'livi': 0, 'ivi': 0, 'vi': 3, 'i': 192, '': 0}
# {'n': 3, 'nb': 0}
# {'b': 11, '': 0}
# {'s': 9, 'st': 3, 'sty': 0, 'styr': 0, 'styre': 0, 'styrel': 0, 'styrels': 0, 'styrelse': 1, 'styrelseu': 0, 'styrelseun': 0, 'styrelseund': 0, 'styrelseunde': 0, 'styrelseunder': 0, 'styrelseunders': 0}
# {'tyrelseunders': 0, 'yrelseunders': 0, 'relseunders': 0, 'elseunders': 0, 'lseunders': 0, 'seunders': 0, 'eunders': 0, 'unders': 0, 'nders': 1, 'ders': 1, 'ers': 8, 'rs': 0, 's': 656, '': 0}
# {'p': 0, 'po': 2, 'pok': 0, 'poke': 0, 'pokem': 0, 'pokemo': 0, 'pokemon': 4, 'pokemon-': 0, 'pokemon-k': 0}
# {'okemon-k': 0, 'kemon-k': 0, 'emon-k': 0, 'mon-k': 0, 'on-k': 0, 'n-k': 0, '-k': 0, 'k': 41, '': 0}
# {'o': 0, 'or': 0, 'ore': 0, 'ored': 0, 'oredo': 0, 'oredov': 0, 'oredovi': 0}
# {'redovi': 0, 'edovi': 0, 'dovi': 0, 'ovi': 0, 'vi': 3, 'i': 192, '': 0}
# {'2': 26, '24': 1, '240': 0, '2400': 0}
# {'400': 0, '00': 148, '0': 221, '': 0}
# {'a': 3, 'ab': 2, 'abh': 0, 'abhi': 0, 'abhiy': 0, 'abhiya': 0, 'abhiyan': 1}
# {'bhiyan': 1, 'hiyan': 1, 'iyan': 0, 'yan': 0, 'an': 1355, 'n': 2639, '': 0}
# {'m': 1, 'mi': 1, 'mid': 0, 'midd': 0, 'midda': 0, 'middag': 2, 'middags': 0, 'middagsb': 0, 'middagsbj': 0}
# {'iddagsbj': 0, 'ddagsbj': 0, 'dagsbj': 0, 'agsbj': 0, 'gsbj': 0, 'sbj': 0, 'bj': 0, 'j': 2, '': 0}
# {'h': 0, 'hu': 0, 'hum': 0, 'humm': 0, 'humme': 0, 'hummer': 1, 'hummer?': 1}
# {'ummer?': 0, 'mmer?': 0, 'mer?': 3, 'er?': 118, 'r?': 74, '?': 4278, '': 0}
# {'s': 9, 'sk': 0, 'sky': 1, 'skyp': 0}
# {'kyp': 0, 'yp': 14, 'p': 19, '': 0}
# {'l': 1, 'la': 2, 'lag': 2, 'lags': 0, 'lagst': 0, 'lagsta': 0, 'lagstad': 0}
# {'agstad': 0, 'gstad': 0, 'stad': 1, 'tad': 3, 'ad': 1415, 'd': 158, '': 0}
# {'u': 0, 'ut': 58, 'utt': 0, 'uttö': 0, 'uttöm': 0, 'uttömm': 0, 'uttömma': 0, 'uttömman': 0}
# {'ttömman': 0, 'tömman': 0, 'ömman': 0, 'mman': 1, 'man': 6, 'an': 1355, 'n': 2639, '': 0}
# {'s': 9, 'st': 3, 'stä': 0, 'stäm': 0, 'stämm': 0}
# {'tämm': 0, 'ämm': 0, 'mm': 0, 'm': 67, '': 0}
# {'p': 0, 'på': 946, 'påv': 0, 'påve': 0, 'påver': 0, 'påverk': 0, 'påverka': 16, 'påverkar': 20, 'påverkar?': 1}
# {'åverkar?': 0, 'verkar?': 1, 'erkar?': 0, 'rkar?': 0, 'kar?': 1, 'ar?': 46, 'r?': 74, '?': 4278, '': 0}
# {'i': 1572, 'in': 70, 'int': 0, 'inte': 296, 'inter': 0, 'intern': 1, 'interne': 0, 'internet': 8, 'internets': 0, 'internetsa': 0, 'internetsam': 0, 'internetsamt': 0, 'internetsamta': 0}
# {'nternetsamta': 0, 'ternetsamta': 0, 'ernetsamta': 0, 'rnetsamta': 0, 'netsamta': 0, 'etsamta': 0, 'tsamta': 0, 'samta': 0, 'amta': 0, 'mta': 0, 'ta': 134, 'a': 2904, '': 0}
# {'s': 9, 'so': 0, 'sor': 0, 'sorg': 0}
# {'org': 0, 'rg': 4, 'g': 1974, '': 0}
# {'a': 3, 'ac': 2, 'acc': 0, 'acce': 0, 'accep': 0, 'accept': 0, 'accepte': 0}
# {'ccepte': 0, 'cepte': 0, 'epte': 0, 'pte': 1, 'te': 317, 'e': 489, '': 0}
# {'m': 1, 'me': 0, 'med': 573, 'medv': 0, 'medve': 0, 'medvet': 0, 'medveta': 0, 'medvetan': 0, 'medvetand': 0, 'medvetande': 0, 'medvetandet': 1}
# {'edvetandet': 1, 'dvetandet': 0, 'vetandet': 1, 'etandet': 0, 'tandet': 0, 'andet': 7, 'ndet': 9, 'det': 7, 'et': 413, 't': 2270, '': 0}
# {'ä': 0, 'äm': 0, 'ämb': 0}
# {'mb': 0, 'b': 11, '': 0}
# {'i': 1572, 'in': 70, 'inf': 0, 'infl': 0, 'infly': 0, 'inflyt': 0, 'inflyta': 0, 'inflytan': 0, 'inflytand': 0, 'inflytande': 1}
# {'nflytande': 1, 'flytande': 1, 'lytande': 7, 'ytande': 0, 'tande': 3, 'ande': 12, 'nde': 70, 'de': 196, 'e': 489, '': 0}
# {'c': 2, 'ce': 0, 'cen': 0, 'cent': 0, 'centr': 0, 'centra': 0, 'central': 0, 'centralb': 0, 'centralba': 0, 'centralban': 0, 'centralbank': 0, 'centralbanks': 0, 'centralbanksc': 0}
# {'entralbanksc': 0, 'ntralbanksc': 0, 'tralbanksc': 0, 'ralbanksc': 0, 'albanksc': 0, 'lbanksc': 0, 'banksc': 0, 'anksc': 0, 'nksc': 0, 'ksc': 0, 'sc': 10, 'c': 25, '': 0}
# {'p': 0, 'pu': 0, 'pub': 0, 'publ': 0, 'publi': 0, 'public': 0, 'publice': 0}
# {'ublice': 0, 'blice': 0, 'lice': 0, 'ice': 1, 'ce': 3, 'e': 489, '': 0}
# {'b': 4, 'be': 1, 'bet': 0, 'beta': 0, 'betal': 0, 'betalk': 0, 'betalko': 0}
# {'etalko': 0, 'talko': 0, 'alko': 0, 'lko': 0, 'ko': 0, 'o': 72, '': 0}
# {'b': 4, 'ba': 1, 'bat': 0, 'batt': 0, 'batte': 0, 'batter': 0, 'batteri': 2, 'batterie': 0, 'batteriet': 0}
# {'atteriet': 0, 'tteriet': 0, 'teriet': 0, 'eriet': 0, 'riet': 0, 'iet': 1, 'et': 413, 't': 2270, '': 0}
# {'m': 1, 'me': 0, 'med': 573, 'mede': 0, 'medel': 1, 'medelk': 0, 'medelkl': 0, 'medelkla': 0, 'medelklas': 0, 'medelklass': 0, 'medelklasse': 0}
# {'edelklasse': 0, 'delklasse': 0, 'elklasse': 0, 'lklasse': 0, 'klasse': 0, 'lasse': 0, 'asse': 0, 'sse': 0, 'se': 10, 'e': 489, '': 0}
# {'d': 0, 'de': 585, 'deo': 0, 'deod': 0, 'deodo': 0, 'deodor': 0, 'deodora': 0, 'deodoran': 0, 'deodorant': 0}
# {'eodorant': 0, 'odorant': 0, 'dorant': 0, 'orant': 0, 'rant': 0, 'ant': 13, 'nt': 18, 't': 2270, '': 0}
# {'c': 2, 'ci': 0, 'cit': 0, 'citr': 0, 'citro': 0, 'citron': 0, 'citronv': 0}
# {'itronv': 0, 'tronv': 0, 'ronv': 0, 'onv': 0, 'nv': 0, 'v': 613, '': 0}
# {'r': 4, 'ra': 0, 'ram': 5, 'rama': 0, 'ramay': 0, 'ramaya': 0}
# {'amaya': 0, 'maya': 0, 'aya': 1, 'ya': 53, 'a': 2904, '': 0}
# {'l': 1, 'le': 1, 'leo': 0, 'leon': 0}
# {'eon': 1, 'on': 16, 'n': 2639, '': 0}
# {'i': 1572, 'ic': 0, 'ick': 0, 'icke': 9, 'icke-': 0, 'icke-i': 0, 'icke-is': 0, 'icke-isl': 0, 'icke-isla': 0, 'icke-islam': 0, 'icke-islami': 0, 'icke-islamis': 0}
# {'cke-islamis': 0, 'ke-islamis': 0, 'e-islamis': 0, '-islamis': 0, 'islamis': 0, 'slamis': 0, 'lamis': 0, 'amis': 0, 'mis': 0, 'is': 8, 's': 656, '': 0}
# {'t': 2, 'tw': 0, 'twi': 0, 'twit': 0}
# {'wit': 0, 'it': 53, 't': 2270, '': 0}
# {'(': 1, '(a': 0, '(ab': 0, '(abc': 0, '(abc)': 1}
# {'abc)': 1, 'bc)': 0, 'c)': 1, ')': 38, '': 0}
# {'h': 0, 'ht': 0, 'htt': 0, 'http': 0, 'http-': 0, 'http-w': 0, 'http-we': 0, 'http-web': 0, 'http-webb': 0, 'http-webbp': 0}
# {'ttp-webbp': 0, 'tp-webbp': 0, 'p-webbp': 0, '-webbp': 0, 'webbp': 0, 'ebbp': 0, 'bbp': 0, 'bp': 0, 'p': 19, '': 0}
# {'w': 3, 'ww': 0, 'www': 0, 'www.': 0, 'www.f': 0, 'www.fi': 0, 'www.fil': 0, 'www.film': 0, 'www.films': 0, 'www.filmsk': 0, 'www.filmski': 0, 'www.filmskil': 0, 'www.filmskill': 0, 'www.filmskills': 0, 'www.filmskills.': 0, 'www.filmskills.c': 0, 'www.filmskills.co': 0, 'www.filmskills.com': 1}
# {'ww.filmskills.com': 1, 'w.filmskills.com': 0, '.filmskills.com': 0, 'filmskills.com': 0, 'ilmskills.com': 0, 'lmskills.com': 0, 'mskills.com': 0, 'skills.com': 0, 'kills.com': 0, 'ills.com': 0, 'lls.com': 0, 'ls.com': 0, 's.com': 0, '.com': 1, 'com': 1, 'om': 752, 'm': 67, '': 0}
# {'r': 4, 'rå': 1, 'råd': 15, 'råde': 0, 'rådet': 3}
# {'ådet': 3, 'det': 7, 'et': 413, 't': 2270, '': 0}
# {'u': 0, 'un': 0, 'und': 0, 'unde': 0}
# {'nde': 70, 'de': 196, 'e': 489, '': 0}
# {'g': 4, 'gr': 1, 'gru': 0, 'grun': 0, 'grund': 11, 'grundä': 0}
# {'rundä': 0, 'undä': 0, 'ndä': 0, 'dä': 0, 'ä': 0, '': 0}
# {'s': 9, 'sö': 0, 'söm': 0, 'sömn': 1, 'sömnf': 0, 'sömnfö': 0, 'sömnför': 0}
# {'ömnför': 0, 'mnför': 0, 'nför': 8, 'för': 614, 'ör': 1300, 'r': 1785, '': 0}
# {'v': 2, 'va': 0, 'vas': 0, 'vass': 0, 'vassl': 0, 'vassle': 0, 'vasslep': 0}
# {'asslep': 0, 'sslep': 0, 'slep': 0, 'lep': 0, 'ep': 2, 'p': 19, '': 0}
# {'s': 9, 'sy': 1, 'syf': 0}
# {'yf': 0, 'f': 0, '': 0}
# {'l': 1, 'lä': 0, 'län': 0, 'läng': 0, 'längs': 1, 'längst': 1, 'längsta': 1}
# {'ängsta': 1, 'ngsta': 0, 'gsta': 0, 'sta': 84, 'ta': 134, 'a': 2904, '': 0}
# {'a': 3, 'av': 577, 'avi': 0, 'avin': 0, 'avins': 0, 'avinst': 0, 'avinsta': 0, 'avinstal': 0, 'avinstall': 0, 'avinstalle': 0, 'avinstaller': 0, 'avinstallera': 1}
# {'vinstallera': 1, 'installera': 1, 'nstallera': 5, 'stallera': 5, 'tallera': 0, 'allera': 0, 'llera': 0, 'lera': 7, 'era': 34, 'ra': 320, 'a': 2904, '': 0}
# {'r': 4, 'ra': 0, 'rap': 0, 'rapp': 0, 'rappo': 0}
# {'appo': 0, 'ppo': 0, 'po': 0, 'o': 72, '': 0}
# {'d': 0, 'di': 0, 'dis': 0, 'disk': 0}
# {'isk': 33, 'sk': 24, 'k': 41, '': 0}
# {'b': 4, 'be': 1, 'bef': 0, 'befo': 0, 'befol': 0, 'befolk': 0, 'befolkn': 0, 'befolkni': 0, 'befolknin': 0, 'befolkning': 1, 'befolkninge': 0}
# {'efolkninge': 0, 'folkninge': 0, 'olkninge': 0, 'lkninge': 0, 'kninge': 0, 'ninge': 0, 'inge': 0, 'nge': 0, 'ge': 3, 'e': 489, '': 0}
# {'2': 26, '24': 1, '24-': 0}
# {'4-': 0, '-': 25, '': 0}
# {'(': 1, '(f': 0, '(fi': 0, '(fik': 0, '(fikt': 0}
# {'fikt': 0, 'ikt': 31, 'kt': 33, 't': 2270, '': 0}
# {'b': 4, 'ba': 1, 'bac': 0, 'back': 1, 'backe': 0, 'backen': 0, 'backend': 0, 'backend-': 0, 'backend-u': 0, 'backend-ut': 0, 'backend-utv': 0, 'backend-utve': 0, 'backend-utvec': 0, 'backend-utveck': 0, 'backend-utveckl': 0}
# {'ackend-utveckl': 0, 'ckend-utveckl': 0, 'kend-utveckl': 0, 'end-utveckl': 0, 'nd-utveckl': 0, 'd-utveckl': 0, '-utveckl': 0, 'utveckl': 0, 'tveckl': 0, 'veckl': 0, 'eckl': 0, 'ckl': 0, 'kl': 1, 'l': 470, '': 0}
# {'i': 1572, 'in': 70, 'ins': 0, 'inst': 0, 'instr': 0, 'instru': 0, 'instruk': 0, 'instrukt': 0, 'instrukti': 0, 'instruktio': 0, 'instruktion': 0, 'instruktione': 0}
# {'nstruktione': 0, 'struktione': 0, 'truktione': 0, 'ruktione': 0, 'uktione': 0, 'ktione': 0, 'tione': 0, 'ione': 0, 'one': 2, 'ne': 12, 'e': 489, '': 0}
# {'o': 0, 'oe': 0, 'oer': 0, 'oerf': 0, 'oerfa': 0, 'oerfar': 0, 'oerfare': 0, 'oerfaren': 1}
# {'erfaren': 0, 'rfaren': 1, 'faren': 1, 'aren': 4, 'ren': 8, 'en': 811, 'n': 2639, '': 0}
# {'f': 2, 'fa': 0, 'fav': 0, 'favo': 0, 'favor': 0, 'favori': 0, 'favorit': 8, 'favoritf': 0, 'favoritfl': 0}
# {'avoritfl': 0, 'voritfl': 0, 'oritfl': 0, 'ritfl': 0, 'itfl': 0, 'tfl': 0, 'fl': 0, 'l': 470, '': 0}
# {'o': 0, 'om': 593, 'ome': 0, 'omed': 0}
# {'med': 4, 'ed': 580, 'd': 158, '': 0}
# {'s': 9, 'sy': 1, 'syd': 0, 'sydn': 0, 'sydne': 0, 'sydney': 3, 'sydney-': 0, 'sydney-o': 0, 'sydney-om': 0, 'sydney-omr': 0, 'sydney-områ': 0, 'sydney-områd': 0, 'sydney-område': 0, 'sydney-området': 0}
# {'ydney-området': 0, 'dney-området': 0, 'ney-området': 0, 'ey-området': 0, 'y-området': 1, '-området': 1, 'området': 1, 'mrådet': 0, 'rådet': 2, 'ådet': 3, 'det': 7, 'et': 413, 't': 2270, '': 0}
# {'e': 11, 'en': 1359, 'end': 0, 'endo': 0, 'endok': 0, 'endokr': 0, 'endokri': 0, 'endokrin': 0}
# {'ndokrin': 0, 'dokrin': 0, 'okrin': 0, 'krin': 0, 'rin': 0, 'in': 434, 'n': 2639, '': 0}
# {'l': 1, 'lä': 0, 'län': 0, 'länk': 1, 'länka': 1, 'länkat': 0, 'länkat?': 1}
# {'änkat?': 1, 'nkat?': 0, 'kat?': 0, 'at?': 12, 't?': 227, '?': 4278, '': 0}
# {'n': 3, 'na': 0, 'nat': 0, 'nati': 0, 'natio': 0, 'nation': 0, 'nationa': 0, 'national': 4, 'nationali': 0, 'nationalis': 0, 'nationalist': 0, 'nationaliste': 0, 'nationalister': 1}
# {'ationalister': 1, 'tionalister': 0, 'ionalister': 0, 'onalister': 0, 'nalister': 0, 'alister': 0, 'lister': 0, 'ister': 5, 'ster': 6, 'ter': 21, 'er': 769, 'r': 1785, '': 0}
# {'f': 2, 'fo': 0, 'for': 2, 'fors': 0, 'forsk': 0, 'forskn': 0, 'forskni': 0, 'forsknin': 0, 'forskning': 1, 'forsknings': 0, 'forskningse': 0, 'forskningser': 0, 'forskningserf': 0, 'forskningserfa': 0, 'forskningserfar': 0, 'forskningserfare': 0, 'forskningserfaren': 0}
# {'orskningserfaren': 0, 'rskningserfaren': 0, 'skningserfaren': 0, 'kningserfaren': 0, 'ningserfaren': 0, 'ingserfaren': 0, 'ngserfaren': 0, 'gserfaren': 0, 'serfaren': 0, 'erfaren': 0, 'rfaren': 1, 'faren': 1, 'aren': 4, 'ren': 8, 'en': 811, 'n': 2639, '': 0}
# {'b': 4, 'b.': 0, 'b.c': 0, 'b.co': 0, 'b.com': 0}
# {'.com': 1, 'com': 1, 'om': 752, 'm': 67, '': 0}
# {'k': 1, 'ko': 0, 'kom': 8, 'komm': 0, 'komme': 0, 'kommen': 0, 'komment': 0, 'kommenta': 0, 'kommentar': 1, 'kommentar)': 1}
# {'ommentar)': 1, 'mmentar)': 0, 'mentar)': 1, 'entar)': 0, 'ntar)': 0, 'tar)': 0, 'ar)': 0, 'r)': 0, ')': 38, '': 0}
# {'m': 1, 'me': 0, 'med': 573, 'medb': 0, 'medbo': 0, 'medbor': 0, 'medborg': 0, 'medborga': 0, 'medborgar': 0, 'medborgars': 0}
# {'edborgars': 0, 'dborgars': 0, 'borgars': 0, 'orgars': 0, 'rgars': 0, 'gars': 3, 'ars': 13, 'rs': 0, 's': 656, '': 0}
# {'n': 3, 'nj': 0, 'nj?': 1}
# {'j?': 2, '?': 4278, '': 0}
# {'0': 0, '0,': 1, '0,2': 0, '0,20': 0, '0,20.': 0}
# {',20.': 0, '20.': 0, '0.': 0, '.': 211, '': 0}
# {'f': 2, 'fl': 0, 'fli': 0, 'flim': 1}
# {'lim': 1, 'im': 14, 'm': 67, '': 0}
# {'r': 4, 'rö': 0, 'rös': 0, 'röst': 0, 'röstm': 0, 'röstme': 0, 'röstmed': 0, 'röstmedd': 0, 'röstmedde': 0, 'röstmeddel': 0, 'röstmeddela': 0, 'röstmeddelan': 0, 'röstmeddeland': 0, 'röstmeddelande': 0, 'röstmeddelanden': 0}
# {'östmeddelanden': 0, 'stmeddelanden': 0, 'tmeddelanden': 0, 'meddelanden': 4, 'eddelanden': 3, 'ddelanden': 0, 'delanden': 3, 'elanden': 0, 'landen': 0, 'anden': 0, 'nden': 7, 'den': 9, 'en': 811, 'n': 2639, '': 0}
# {'k': 1, 'ko': 0, 'kor': 1, 'korr': 0, 'korri': 0, 'korrig': 0, 'korrige': 0, 'korriger': 0, 'korrigera': 0, 'korrigerad': 0, 'korrigerad?': 1}
# {'orrigerad?': 1, 'rrigerad?': 0, 'rigerad?': 1, 'igerad?': 0, 'gerad?': 0, 'erad?': 1, 'rad?': 1, 'ad?': 7, 'd?': 43, '?': 4278, '': 0}
# {'b': 4, 'be': 1, 'bef': 0, 'befa': 0, 'befat': 0, 'befatt': 0, 'befattn': 0, 'befattni': 0}
# {'efattni': 0, 'fattni': 0, 'attni': 0, 'ttni': 0, 'tni': 0, 'ni': 3, 'i': 192, '': 0}
# {'c': 2, 'cs': 1, 'cs)': 0}
# {'s)': 0, ')': 38, '': 0}
# {'f': 2, 'fi': 0, 'fil': 2, 'film': 18, 'filmh': 0, 'filmhi': 0, 'filmhis': 0, 'filmhist': 0}
# {'ilmhist': 0, 'lmhist': 0, 'mhist': 0, 'hist': 0, 'ist': 3, 'st': 34, 't': 2270, '': 0}
# {'p': 0, 'pa': 2, 'pab': 0}
# {'ab': 0, 'b': 11, '': 0}
# {'s': 9, 'sj': 0, 'sju': 2, 'sjuk': 1, 'sjukv': 0, 'sjukvå': 0, 'sjukvår': 0, 'sjukvård': 1}
# {'jukvård': 1, 'ukvård': 0, 'kvård': 1, 'vård': 1, 'ård': 0, 'rd': 4, 'd': 158, '': 0}
# {'m': 1, 'ma': 0, 'mau': 0, 'maus': 0}
# {'aus': 0, 'us': 8, 's': 656, '': 0}
# {'u': 0, 'us': 0, 'us$': 0, 'us$6': 0, 'us$60': 0, 'us$600': 0, 'us$6000': 1}
# {'s$6000': 0, '$6000': 0, '6000': 0, '000': 82, '00': 148, '0': 221, '': 0}
# {'f': 2, 'fe': 0, 'feb': 0, 'febr': 0, 'febru': 0}
# {'ebru': 0, 'bru': 0, 'ru': 5, 'u': 22, '': 0}
# {'b': 4, 'bo': 18, 'boo': 0, 'boot': 0, 'boots': 0, 'bootst': 0, 'bootstr': 0, 'bootstra': 0, 'bootstrap': 0}
# {'ootstrap': 0, 'otstrap': 0, 'tstrap': 0, 'strap': 0, 'trap': 0, 'rap': 0, 'ap': 6, 'p': 19, '': 0}
# {'y': 0, 'yr': 0, 'yrk': 0, 'yrke': 1, 'yrkes': 0, 'yrkesv': 0, 'yrkesve': 0, 'yrkesver': 0, 'yrkesverk': 0, 'yrkesverks': 0, 'yrkesverksa': 0, 'yrkesverksam': 0, 'yrkesverksamm': 0, 'yrkesverksamma': 0}
# {'rkesverksamma': 0, 'kesverksamma': 0, 'esverksamma': 0, 'sverksamma': 0, 'verksamma': 0, 'erksamma': 0, 'rksamma': 0, 'ksamma': 0, 'samma': 7, 'amma': 25, 'mma': 24, 'ma': 60, 'a': 2904, '': 0}
# {'l': 1, 'lå': 0, 'lås': 1, 'lås?': 1}
# {'ås?': 1, 's?': 84, '?': 4278, '': 0}
# {'p': 0, 'pr': 1, 'pro': 8, 'prob': 0, 'probl': 0, 'proble': 0, 'problem': 12, 'probleme': 0, 'problemen': 2}
# {'roblemen': 0, 'oblemen': 2, 'blemen': 2, 'lemen': 0, 'emen': 0, 'men': 21, 'en': 811, 'n': 2639, '': 0}
# {'r': 4, 're': 0, 'res': 0}
# {'es': 27, 's': 656, '': 0}
# {'h': 0, 'hy': 1, 'hyl': 0, 'hyls': 0, 'hylso': 0, 'hylsor': 0}
# {'ylsor': 0, 'lsor': 0, 'sor': 2, 'or': 34, 'r': 1785, '': 0}
# {'r': 4, 'ra': 0, 'ram': 5, 'ramv': 0, 'ramve': 0, 'ramver': 0, 'ramverk': 1, 'ramverke': 0, 'ramverken': 1}
# {'amverken': 1, 'mverken': 0, 'verken': 1, 'erken': 0, 'rken': 0, 'ken': 18, 'en': 811, 'n': 2639, '': 0}
# {'a': 3, 'au': 0, 'aut': 0, 'aute': 0}
# {'ute': 0, 'te': 317, 'e': 489, '': 0}
# {'b': 4, 'br': 1, 'bra': 180, 'bram': 0, 'bram-': 0, 'bram-i': 0, 'bram-in': 0, 'bram-inn': 0, 'bram-inne': 0, 'bram-inneh': 0, 'bram-innehå': 0}
# {'ram-innehå': 0, 'am-innehå': 0, 'm-innehå': 0, '-innehå': 0, 'innehå': 0, 'nnehå': 0, 'nehå': 0, 'ehå': 0, 'hå': 0, 'å': 433, '': 0}
# {'b': 4, 'br': 1, 'bra': 180, 'bras': 0}
# {'ras': 29, 'as': 96, 's': 656, '': 0}
# {'t': 2, 'tr': 0, 'tra': 0, 'tran': 0, 'trans': 0, 'transm': 0, 'transmi': 0, 'transmis': 0}
# {'ransmis': 0, 'ansmis': 0, 'nsmis': 0, 'smis': 0, 'mis': 0, 'is': 8, 's': 656, '': 0}
# {'"': 2, '""': 13, '""s': 0, '""sa': 0, '""san': 0}
# {'"san': 0, 'san': 1, 'an': 1355, 'n': 2639, '': 0}
# {'t': 2, 'te': 10, 'ten': 0, 'teno': 0, 'tenoc': 0, 'tenoch': 0, 'tenocht': 0, 'tenochti': 0}
# {'enochti': 0, 'nochti': 0, 'ochti': 0, 'chti': 0, 'hti': 0, 'ti': 6, 'i': 192, '': 0}
# {'r': 4, 'ra': 0, 'rav': 0, 'ravi': 0, 'ravin': 0, 'ravind': 0, 'ravindr': 0, 'ravindra': 0, 'ravindrab': 0, 'ravindraba': 0}
# {'avindraba': 0, 'vindraba': 0, 'indraba': 0, 'ndraba': 0, 'draba': 0, 'raba': 0, 'aba': 0, 'ba': 11, 'a': 2904, '': 0}
# {'ö': 0, 'öv': 0, 'övn': 0, 'övni': 0, 'övnin': 0, 'övning': 0, 'övninga': 0}
# {'vninga': 0, 'ninga': 0, 'inga': 3, 'nga': 127, 'ga': 15, 'a': 2904, '': 0}
# {'r': 4, 'rä': 0, 'rät': 0, 'rätt': 12, 'rätts': 0, 'rättss': 0, 'rättssk': 0, 'rättssky': 0, 'rättsskyd': 0, 'rättsskydd': 0, 'rättsskydds': 0, 'rättsskyddsk': 0}
# {'ättsskyddsk': 0, 'ttsskyddsk': 0, 'tsskyddsk': 0, 'sskyddsk': 0, 'skyddsk': 0, 'kyddsk': 0, 'yddsk': 0, 'ddsk': 0, 'dsk': 0, 'sk': 24, 'k': 41, '': 0}
# {'p': 0, 'på': 946, 'påh': 0}
# {'åh': 0, 'h': 4, '': 0}
# {'5': 22, '5-': 0, '5-s': 0, '5-st': 0, '5-stj': 0, '5-stjä': 0, '5-stjär': 0, '5-stjärn': 0, '5-stjärni': 0, '5-stjärnig': 0}
# {'-stjärnig': 0, 'stjärnig': 0, 'tjärnig': 0, 'järnig': 0, 'ärnig': 0, 'rnig': 0, 'nig': 0, 'ig': 389, 'g': 1974, '': 0}
# {'p': 0, 'pr': 1, 'pro': 8, 'pro-': 0, 'pro-e': 0, 'pro-et': 0}
# {'ro-et': 0, 'o-et': 0, '-et': 0, 'et': 413, 't': 2270, '': 0}
# {'k': 1, 'ka': 0, 'kan': 1003, 'kans': 0}
# {'ans': 5, 'ns': 53, 's': 656, '': 0}
# {'s': 9, 'sj': 0, 'sjä': 0, 'själ': 1, 'själv': 20, 'självm': 0, 'självmo': 0, 'självmor': 0, 'självmord': 7}
# {'jälvmord': 7, 'älvmord': 0, 'lvmord': 0, 'vmord': 7, 'mord': 7, 'ord': 11, 'rd': 4, 'd': 158, '': 0}
# {'a': 3, 'av': 577, 'avs': 0, 'avsä': 0, 'avsän': 0, 'avsänd': 0, 'avsända': 0, 'avsändar': 0, 'avsändare': 0, 'avsändaren': 0}
# {'vsändaren': 0, 'sändaren': 0, 'ändaren': 0, 'ndaren': 0, 'daren': 0, 'aren': 4, 'ren': 8, 'en': 811, 'n': 2639, '': 0}
# {'b': 4, 'ba': 1, 'bal': 0, 'balu': 0, 'baluc': 0, 'baluch': 0, 'baluchi': 0, 'baluchis': 0, 'baluchist': 0, 'baluchista': 0, 'baluchistan': 0}
# {'aluchistan': 0, 'luchistan': 0, 'uchistan': 0, 'chistan': 0, 'histan': 0, 'istan': 13, 'stan': 0, 'tan': 0, 'an': 1355, 'n': 2639, '': 0}
# {'k': 1, 'ke': 0, 'ket': 0, 'ketc': 0}
# {'etc': 0, 'tc': 1, 'c': 25, '': 0}
# {'b': 4, 'bi': 2, 'bio': 0}
# {'io': 8, 'o': 72, '': 0}
# {'s': 9, 'sa': 7, 'sar': 0, 'sark': 0, 'sarka': 0, 'sarkas': 0, 'sarkast': 0}
# {'arkast': 0, 'rkast': 0, 'kast': 0, 'ast': 11, 'st': 34, 't': 2270, '': 0}
# {'t': 2, 'tr': 0, 'trä': 0, 'trän': 0, 'träni': 0, 'tränin': 0, 'träning': 1, 'tränings': 0, 'träningsc': 0, 'träningsce': 0, 'träningscen': 0, 'träningscent': 0}
# {'räningscent': 0, 'äningscent': 0, 'ningscent': 0, 'ingscent': 0, 'ngscent': 0, 'gscent': 0, 'scent': 0, 'cent': 5, 'ent': 8, 'nt': 18, 't': 2270, '': 0}
# {'s': 9, 'so': 0, 'sol': 0, 'sold': 0, 'solda': 0, 'soldat': 0, 'soldate': 0, 'soldater': 1, 'soldatern': 0}
# {'oldatern': 0, 'ldatern': 0, 'datern': 0, 'atern': 0, 'tern': 1, 'ern': 0, 'rn': 19, 'n': 2639, '': 0}
# {'l': 1, 'lä': 0, 'läk': 0}
# {'äk': 0, 'k': 41, '': 0}
# {'s': 9, 'sa': 7, 'sam': 0, 'samt': 1, 'samta': 0, 'samtal': 14, 'samtals': 0, 'samtalsh': 0, 'samtalshi': 0, 'samtalshis': 0}
# {'amtalshis': 0, 'mtalshis': 0, 'talshis': 0, 'alshis': 0, 'lshis': 0, 'shis': 0, 'his': 1, 'is': 8, 's': 656, '': 0}
# {'r': 4, 'rp': 0, 'rps': 1}
# {'ps': 6, 's': 656, '': 0}
# {'s': 9, 'sg': 0, 'sgp': 0}
# {'gp': 0, 'p': 19, '': 0}
# {'s': 9, 'st': 3, 'sta': 0, 'stab': 0, 'stabi': 0, 'stabil': 0, 'stabila': 1}
# {'tabila': 1, 'abila': 1, 'bila': 0, 'ila': 3, 'la': 114, 'a': 2904, '': 0}
# {'a': 3, 'ar': 0, 'arb': 0, 'arbe': 0, 'arbet': 0, 'arbets': 1, 'arbetst': 0, 'arbetsti': 0, 'arbetstit': 0, 'arbetstite': 0, 'arbetstitel': 0}
# {'rbetstitel': 0, 'betstitel': 0, 'etstitel': 0, 'tstitel': 0, 'stitel': 0, 'titel': 0, 'itel': 0, 'tel': 6, 'el': 14, 'l': 470, '': 0}
# {'t': 2, 'ti': 0, 'til': 1, 'till': 394, 'tillh': 0, 'tillha': 0}
# {'illha': 0, 'llha': 0, 'lha': 0, 'ha': 2, 'a': 2904, '': 0}
# {'f': 2, 'fö': 0, 'för': 1109, 'förk': 0, 'förky': 0, 'förkyl': 0, 'förkyln': 0, 'förkylni': 0, 'förkylnin': 0, 'förkylning': 2, 'förkylninga': 0, 'förkylningar': 0, 'förkylningar?': 1}
# {'örkylningar?': 1, 'rkylningar?': 0, 'kylningar?': 1, 'ylningar?': 0, 'lningar?': 0, 'ningar?': 3, 'ingar?': 1, 'ngar?': 1, 'gar?': 13, 'ar?': 46, 'r?': 74, '?': 4278, '': 0}
# {'k': 1, 'ko': 0, 'kom': 8, 'komp': 0, 'kompe': 0, 'kompen': 0, 'kompens': 0, 'kompense': 0, 'kompenser': 0}
# {'ompenser': 0, 'mpenser': 0, 'penser': 0, 'enser': 1, 'nser': 15, 'ser': 10, 'er': 769, 'r': 1785, '': 0}
# {'i': 1572, 'in': 70, 'ink': 0, 'inkl': 0, 'inklu': 0}
# {'nklu': 0, 'klu': 0, 'lu': 0, 'u': 22, '': 0}
# {'n': 3, 'ne': 0, 'nef': 0, 'neft': 0, 'neft-': 0, 'neft-f': 0, 'neft-fo': 0, 'neft-fon': 0, 'neft-fond': 0, 'neft-fondö': 0, 'neft-fondöv': 0, 'neft-fondöve': 0, 'neft-fondöver': 0, 'neft-fondöverf': 0, 'neft-fondöverfö': 0, 'neft-fondöverför': 0}
# {'eft-fondöverför': 0, 'ft-fondöverför': 0, 't-fondöverför': 0, '-fondöverför': 0, 'fondöverför': 0, 'ondöverför': 0, 'ndöverför': 0, 'döverför': 0, 'överför': 0, 'verför': 0, 'erför': 1, 'rför': 0, 'för': 614, 'ör': 1300, 'r': 1785, '': 0}
# {'l': 1, 'l1': 0, 'l1b': 0, 'l1b-': 0, 'l1b-v': 0, 'l1b-vi': 0}
# {'1b-vi': 0, 'b-vi': 0, '-vi': 0, 'vi': 3, 'i': 192, '': 0}
# {'s': 9, 'sp': 0, 'spe': 0, 'spek': 0}
# {'pek': 0, 'ek': 0, 'k': 41, '': 0}
# {'b': 4, 'bä': 0, 'bän': 0, 'bänk': 0, 'bänkp': 0}
# {'änkp': 0, 'nkp': 0, 'kp': 0, 'p': 19, '': 0}
# {'b': 4, 'br': 1, 'bra': 180, 'brai': 0, 'brain': 0, 'brain-': 0, 'brain-c': 0, 'brain-co': 0}
# {'rain-co': 0, 'ain-co': 0, 'in-co': 0, 'n-co': 0, '-co': 0, 'co': 1, 'o': 72, '': 0}
# {'l': 1, 'le': 1, 'lev': 0, 'leve': 0, 'lever': 6, 'levera': 0, 'leveran': 0, 'leverant': 0, 'leverantö': 0, 'leverantör': 0, 'leverantörs': 0, 'leverantörsk': 0, 'leverantörsko': 0, 'leverantörskon': 0, 'leverantörskons': 0, 'leverantörskonsu': 0, 'leverantörskonsul': 0, 'leverantörskonsult': 0}
# {'everantörskonsult': 0, 'verantörskonsult': 0, 'erantörskonsult': 0, 'rantörskonsult': 0, 'antörskonsult': 0, 'ntörskonsult': 0, 'törskonsult': 0, 'örskonsult': 0, 'rskonsult': 0, 'skonsult': 0, 'konsult': 0, 'onsult': 1, 'nsult': 0, 'sult': 1, 'ult': 2, 'lt': 12, 't': 2270, '': 0}
# {'h': 0, 'hi': 0, 'hin': 0, 'hind': 0, 'hindu': 2, 'hindus': 0, 'hindust': 0}
# {'indust': 0, 'ndust': 0, 'dust': 0, 'ust': 1, 'st': 34, 't': 2270, '': 0}
# {'s': 9, 'sh': 0, 'shi': 0, 'shie': 0}
# {'hie': 0, 'ie': 2, 'e': 489, '': 0}
# {'a': 3, 'at': 0, 'att': 1660, 'atta': 0, 'attac': 0, 'attack': 2, 'attacke': 0, 'attacker': 0, 'attackera': 2, 'attackerar': 1}
# {'ttackerar': 1, 'tackerar': 0, 'ackerar': 1, 'ckerar': 0, 'kerar': 1, 'erar': 37, 'rar': 5, 'ar': 527, 'r': 1785, '': 0}
# {'f': 2, 'fa': 0, 'fam': 0, 'fami': 0, 'famil': 0, 'familj': 3, 'familje': 0, 'familjeb': 0, 'familjeba': 0, 'familjebak': 0, 'familjebakg': 0, 'familjebakgr': 0, 'familjebakgru': 0, 'familjebakgrun': 0}
# {'amiljebakgrun': 0, 'miljebakgrun': 0, 'iljebakgrun': 0, 'ljebakgrun': 0, 'jebakgrun': 0, 'ebakgrun': 0, 'bakgrun': 0, 'akgrun': 0, 'kgrun': 0, 'grun': 0, 'run': 1, 'un': 3, 'n': 2639, '': 0}
# {'f': 2, 'fa': 0, 'fac': 0, 'face': 0, 'faceb': 0, 'facebo': 0, 'faceboo': 0, 'facebook': 20, 'facebook-': 0, 'facebook-v': 0, 'facebook-va': 0, 'facebook-var': 0, 'facebook-varn': 0, 'facebook-varni': 0, 'facebook-varnin': 0, 'facebook-varning': 0, 'facebook-varninga': 0}
# {'acebook-varninga': 0, 'cebook-varninga': 0, 'ebook-varninga': 0, 'book-varninga': 0, 'ook-varninga': 0, 'ok-varninga': 0, 'k-varninga': 0, '-varninga': 0, 'varninga': 0, 'arninga': 0, 'rninga': 0, 'ninga': 0, 'inga': 3, 'nga': 127, 'ga': 15, 'a': 2904, '': 0}
# {'v': 2, 'vr': 1, 'vra': 0, 'vray': 0, 'vray-': 0, 'vray-å': 0, 'vray-åt': 0, 'vray-åte': 0, 'vray-åter': 0, 'vray-återg': 0}
# {'ray-återg': 0, 'ay-återg': 0, 'y-återg': 0, '-återg': 0, 'återg': 0, 'terg': 0, 'erg': 0, 'rg': 4, 'g': 1974, '': 0}
# {'w': 3, 'wh': 0, 'wha': 0, 'whar': 0}
# {'har': 2, 'ar': 527, 'r': 1785, '': 0}
# {'b': 4, 'bi': 2, 'bio': 0, 'biot': 0, 'biote': 0, 'biotec': 0, 'biotech': 0, 'biotechn': 0, 'biotechno': 0, 'biotechnol': 0, 'biotechnolo': 0, 'biotechnolog': 0, 'biotechnology': 0}
# {'iotechnology': 0, 'otechnology': 0, 'technology': 0, 'echnology': 2, 'chnology': 2, 'hnology': 0, 'nology': 2, 'ology': 0, 'logy': 0, 'ogy': 0, 'gy': 0, 'y': 36, '': 0}
# {'i': 1572, 'in': 70, 'int': 0, 'inte': 296, 'inter': 0, 'intern': 1, 'interne': 0, 'internet': 8, 'internetl': 0, 'internetle': 0, 'internetlev': 0, 'internetleve': 0, 'internetlever': 0, 'internetlevera': 0, 'internetleveran': 0}
# {'nternetleveran': 0, 'ternetleveran': 0, 'ernetleveran': 0, 'rnetleveran': 0, 'netleveran': 0, 'etleveran': 0, 'tleveran': 0, 'leveran': 0, 'everan': 0, 'veran': 0, 'eran': 1, 'ran': 6, 'an': 1355, 'n': 2639, '': 0}
# {'g': 4, 'gr': 1, 'gre': 4, 'gree': 0, 'green': 1}
# {'reen': 1, 'een': 2, 'en': 811, 'n': 2639, '': 0}
# {'b': 4, 'bo': 18, 'boo': 0, 'book': 1, 'bookm': 0, 'bookma': 0, 'bookmar': 0, 'bookmark': 0, 'bookmarki': 0, 'bookmarkin': 0}
# {'ookmarkin': 0, 'okmarkin': 0, 'kmarkin': 0, 'markin': 0, 'arkin': 0, 'rkin': 0, 'kin': 2, 'in': 434, 'n': 2639, '': 0}
# {'t': 2, 'tu': 0, 'tur': 1, 'turn': 0, 'turne': 0, 'turner': 1}
# {'urner': 1, 'rner': 0, 'ner': 41, 'er': 769, 'r': 1785, '': 0}
# {'k': 1, 'ko': 0, 'kok': 0, 'koka': 0, 'kokan': 0}
# {'okan': 0, 'kan': 7, 'an': 1355, 'n': 2639, '': 0}
# {'f': 2, 'fr': 0, 'fri': 2, 'frid': 0, 'fridf': 0}
# {'ridf': 0, 'idf': 0, 'df': 0, 'f': 0, '': 0}
# {'s': 9, 'sl': 0, 'slu': 0, 'slut': 7, 'slutl': 0, 'slutli': 0, 'slutlig': 0, 'slutlige': 0, 'slutligen': 1}
# {'lutligen': 1, 'utligen': 0, 'tligen': 14, 'ligen': 59, 'igen': 0, 'gen': 58, 'en': 811, 'n': 2639, '': 0}
# {'h': 0, 'ha': 116, 'han': 44, 'hand': 5, 'handi': 0, 'handik': 0, 'handika': 0, 'handikap': 0}
# {'andikap': 0, 'ndikap': 0, 'dikap': 0, 'ikap': 0, 'kap': 0, 'ap': 6, 'p': 19, '': 0}
# {'s': 9, 'so': 0, 'sol': 0, 'sole': 0, 'solen': 2}
# {'olen': 2, 'len': 4, 'en': 811, 'n': 2639, '': 0}
# {'v': 2, 'vä': 0, 'väl': 6, 'väls': 0, 'välsi': 0, 'välsig': 0, 'välsign': 0, 'välsigne': 0, 'välsignel': 0, 'välsignels': 0}
# {'älsignels': 0, 'lsignels': 0, 'signels': 0, 'ignels': 0, 'gnels': 0, 'nels': 0, 'els': 1, 'ls': 7, 's': 656, '': 0}
# {'k': 1, 'ko': 0, 'kol': 1}
# {'ol': 5, 'l': 470, '': 0}
# {'a': 3, 'al': 1, 'alt': 0, 'alte': 0, 'alter': 0, 'altern': 0, 'alterna': 0}
# {'lterna': 0, 'terna': 2, 'erna': 121, 'rna': 44, 'na': 371, 'a': 2904, '': 0}
# {'m': 1, 'mä': 0, 'mär': 0, 'märk': 0, 'märkt': 1, 'märkte': 0}
# {'ärkte': 0, 'rkte': 0, 'kte': 0, 'te': 317, 'e': 489, '': 0}
# {'d': 0, 'di': 0, 'dis': 0, 'dist': 0, 'distr': 0, 'distri': 0, 'distrib': 0, 'distribu': 0}
# {'istribu': 0, 'stribu': 0, 'tribu': 0, 'ribu': 0, 'ibu': 0, 'bu': 0, 'u': 22, '': 0}
# {'p': 0, 'po': 2, 'pol': 0, 'poli': 0, 'polic': 0}
# {'olic': 0, 'lic': 0, 'ic': 1, 'c': 25, '': 0}
# {'o': 0, 'or': 0, 'oro': 0, 'oron': 1}
# {'ron': 2, 'on': 16, 'n': 2639, '': 0}
# {'n': 3, 'na': 0, 'nat': 0, 'natu': 0, 'natur': 0, 'natura': 0, 'natural': 0, 'naturali': 0, 'naturalis': 0, 'naturalise': 0, 'naturaliser': 0, 'naturaliseri': 0, 'naturaliserin': 0}
# {'aturaliserin': 0, 'turaliserin': 0, 'uraliserin': 0, 'raliserin': 0, 'aliserin': 0, 'liserin': 0, 'iserin': 0, 'serin': 0, 'erin': 0, 'rin': 0, 'in': 434, 'n': 2639, '': 0}
# {'s': 9, 'sp': 0, 'spå': 0, 'spår': 2, 'spårb': 0, 'spårba': 0, 'spårbar': 0}
# {'pårbar': 0, 'årbar': 0, 'rbar': 0, 'bar': 6, 'ar': 527, 'r': 1785, '': 0}
# {'o': 0, 'oä': 0, 'oän': 0, 'oänd': 0, 'oändl': 0, 'oändli': 0}
# {'ändli': 0, 'ndli': 0, 'dli': 0, 'li': 121, 'i': 192, '': 0}
# {'i': 1572, 'im': 1, 'imm': 0, 'imma': 0, 'immat': 0, 'immate': 0, 'immater': 0, 'immateri': 0, 'immaterie': 0, 'immateriel': 0}
# {'mmateriel': 0, 'materiel': 0, 'ateriel': 0, 'teriel': 0, 'eriel': 0, 'riel': 0, 'iel': 0, 'el': 14, 'l': 470, '': 0}
# {'f': 2, 'ft': 0, 'ft-': 0, 'ft-b': 0, 'ft-by': 0, 'ft-byg': 0, 'ft-bygg': 0, 'ft-byggn': 0, 'ft-byggna': 0, 'ft-byggnad': 0}
# {'t-byggnad': 0, '-byggnad': 0, 'byggnad': 0, 'yggnad': 0, 'ggnad': 0, 'gnad': 0, 'nad': 11, 'ad': 1415, 'd': 158, '': 0}
# {'j': 0, 'ja': 2, 'jay': 0, 'jaya': 0, 'jayal': 0, 'jayala': 0, 'jayalal': 0, 'jayalali': 0, 'jayalalit': 0, 'jayalalith': 0, 'jayalalitha': 0, 'jayalalitha?': 1}
# {'ayalalitha?': 0, 'yalalitha?': 1, 'alalitha?': 0, 'lalitha?': 0, 'alitha?': 0, 'litha?': 0, 'itha?': 0, 'tha?': 0, 'ha?': 0, 'a?': 195, '?': 4278, '': 0}
# {'v': 2, 'va': 0, 'vai': 0, 'vail': 0, 'vailf': 0, 'vailfi': 0}
# {'ailfi': 0, 'ilfi': 0, 'lfi': 0, 'fi': 0, 'i': 192, '': 0}
# {'n': 3, 'na': 0, 'nat': 0, 'natu': 0, 'natur': 0, 'naturl': 0, 'naturli': 0, 'naturlig': 0, 'naturliga': 3}
# {'aturliga': 3, 'turliga': 0, 'urliga': 0, 'rliga': 0, 'liga': 75, 'iga': 27, 'ga': 15, 'a': 2904, '': 0}
# {'q': 1, 'qu': 0}
# {'u': 22, '': 0}
# {'r': 4, 'rö': 0, 'röd': 2, 'röda': 2}
# {'öda': 2, 'da': 53, 'a': 2904, '': 0}
# {'d': 0, 'dr': 6, 'drö': 0, 'dröm': 4, 'dröm.': 1}
# {'röm.': 0, 'öm.': 1, 'm.': 2, '.': 211, '': 0}
# {'m': 1, 'ma': 0, 'map': 0}
# {'ap': 6, 'p': 19, '': 0}
# {'p': 0, 'po': 2, 'pol': 0, 'poli': 0, 'polit': 0, 'politi': 0, 'politis': 0, 'politisk': 3, 'politiskt': 4}
# {'olitiskt': 0, 'litiskt': 4, 'itiskt': 0, 'tiskt': 0, 'iskt': 6, 'skt': 3, 'kt': 33, 't': 2270, '': 0}
# {'h': 0, 'hå': 0, 'hår': 6, 'håre': 0, 'håret': 5, 'håret?': 2}
# {'året?': 0, 'ret?': 2, 'et?': 131, 't?': 227, '?': 4278, '': 0}
# {'l': 1, 'le': 1, 'led': 0, 'leda': 1, 'ledar': 0, 'ledare': 3, 'ledare?': 1}
# {'edare?': 1, 'dare?': 2, 'are?': 32, 're?': 55, 'e?': 49, '?': 4278, '': 0}
# {'a': 3, 'ar': 0, 'arb': 0, 'arbe': 0, 'arbet': 0, 'arbets': 1, 'arbetsg': 0, 'arbetsgi': 0}
# {'rbetsgi': 0, 'betsgi': 0, 'etsgi': 0, 'tsgi': 0, 'sgi': 0, 'gi': 1, 'i': 192, '': 0}
# {'d': 0, 'do': 0, 'dol': 0, 'doll': 0, 'dolla': 0, 'dollar': 8}
# {'ollar': 1, 'llar': 0, 'lar': 24, 'ar': 527, 'r': 1785, '': 0}
# {'r': 4, 'ro': 0, 'rob': 0, 'robe': 0}
# {'obe': 0, 'be': 2, 'e': 489, '': 0}
# {'2': 26, '20': 11, '200': 3, '2000': 16, '20000': 0, '20000-': 0, '20000-2': 0, '20000-25': 0, '20000-250': 0}
# {'0000-250': 0, '000-250': 0, '00-250': 0, '0-250': 0, '-250': 0, '250': 0, '50': 3, '0': 221, '': 0}
# {'d': 0, 'dy': 0, 'dyr': 1, 'dyra': 3, 'dyra?': 2}
# {'yra?': 0, 'ra?': 16, 'a?': 195, '?': 4278, '': 0}
# {'n': 3, 'ns': 0, 'nsr': 1}
# {'sr': 1, 'r': 1785, '': 0}
# {'s': 9, 'sk': 0, 'ska': 251, 'skad': 0, 'skade': 0, 'skades': 0, 'skadest': 0, 'skadestå': 0, 'skadestån': 0, 'skadestånd': 1, 'skadestånds': 0, 'skadeståndsa': 0, 'skadeståndsan': 0, 'skadeståndsans': 0, 'skadeståndsansp': 0, 'skadeståndsanspr': 0, 'skadeståndsansprå': 0, 'skadeståndsanspråk': 1}
# {'kadeståndsanspråk': 1, 'adeståndsanspråk': 0, 'deståndsanspråk': 1, 'eståndsanspråk': 0, 'ståndsanspråk': 0, 'tåndsanspråk': 0, 'åndsanspråk': 0, 'ndsanspråk': 0, 'dsanspråk': 0, 'sanspråk': 1, 'anspråk': 0, 'nspråk': 1, 'språk': 0, 'pråk': 6, 'råk': 1, 'åk': 1, 'k': 41, '': 0}
# {'a': 3, 'ar': 0, 'arb': 0, 'arbe': 0, 'arbet': 0, 'arbets': 1, 'arbetsg': 0, 'arbetsgi': 0, 'arbetsgiv': 0, 'arbetsgiva': 0}
# {'rbetsgiva': 0, 'betsgiva': 0, 'etsgiva': 0, 'tsgiva': 0, 'sgiva': 0, 'giva': 0, 'iva': 17, 'va': 29, 'a': 2904, '': 0}
# {'b': 4, 'bu': 0, 'bul': 0, 'bulk': 0, 'bulk?': 1}
# {'ulk?': 1, 'lk?': 0, 'k?': 21, '?': 4278, '': 0}
# {'v': 2, 'va': 0, 'vak': 0, 'vakn': 0, 'vakna': 3, 'vaknad': 0}
# {'aknad': 0, 'knad': 0, 'nad': 11, 'ad': 1415, 'd': 158, '': 0}
# {'c': 2, 'co': 0, 'cor': 0, 'corp': 0, 'corpo': 0}
# {'orpo': 0, 'rpo': 0, 'po': 0, 'o': 72, '': 0}
# {'5': 22, '50': 6, '500': 55, '500.': 0, '500.1': 0, '500.10': 0, '500.100': 0, '500.1000': 0, '500.1000.': 0}
# {'00.1000.': 0, '0.1000.': 0, '.1000.': 0, '1000.': 0, '000.': 0, '00.': 0, '0.': 0, '.': 211, '': 0}
# {'z': 0, 'zi': 0, 'zio': 0}
# {'io': 8, 'o': 72, '': 0}
# {'s': 9, 'sk': 0, 'sku': 0, 'skul': 0, 'skuld': 0, 'skuldp': 0, 'skuldpr': 0, 'skuldpro': 0, 'skuldprod': 0, 'skuldprodu': 0, 'skuldproduk': 0, 'skuldprodukt': 0, 'skuldprodukte': 0, 'skuldprodukter': 0}
# {'kuldprodukter': 0, 'uldprodukter': 0, 'ldprodukter': 0, 'dprodukter': 0, 'produkter': 0, 'rodukter': 0, 'odukter': 9, 'dukter': 9, 'ukter': 0, 'kter': 2, 'ter': 21, 'er': 769, 'r': 1785, '': 0}
# {'ö': 0, 'öv': 0, 'öve': 0, 'över': 47, 'övers': 0, 'översy': 0}
# {'versy': 0, 'ersy': 0, 'rsy': 0, 'sy': 0, 'y': 36, '': 0}
# {'c': 2, 'c-': 0, 'c-v': 0}
# {'-v': 0, 'v': 613, '': 0}
# {'d': 0, 'da': 1, 'dat': 0, 'data': 9, 'datat': 0, 'datato': 0, 'datatol': 0, 'datatolk': 0, 'datatolkn': 0, 'datatolkni': 0, 'datatolknin': 0, 'datatolkning': 0, 'datatolknings': 0, 'datatolkningsf': 0, 'datatolkningsfö': 0, 'datatolkningsför': 0, 'datatolkningsförm': 0, 'datatolkningsförmå': 0, 'datatolkningsförmåg': 0}
# {'atatolkningsförmåg': 0, 'tatolkningsförmåg': 0, 'atolkningsförmåg': 0, 'tolkningsförmåg': 0, 'olkningsförmåg': 0, 'lkningsförmåg': 0, 'kningsförmåg': 0, 'ningsförmåg': 0, 'ingsförmåg': 0, 'ngsförmåg': 0, 'gsförmåg': 0, 'sförmåg': 0, 'förmåg': 0, 'örmåg': 0, 'rmåg': 0, 'måg': 0, 'åg': 6, 'g': 1974, '': 0}
# {'t': 2, 'tv': 10, 'tv-': 0, 'tv-k': 0, 'tv-kr': 0, 'tv-kri': 0, 'tv-krit': 0, 'tv-kriti': 0}
# {'v-kriti': 0, '-kriti': 0, 'kriti': 0, 'riti': 1, 'iti': 0, 'ti': 6, 'i': 192, '': 0}
# {'b': 4, 'bi': 2, 'bil': 11, 'bilp': 0, 'bilpo': 0, 'bilpoo': 0, 'bilpool': 0, 'bilpooln': 0, 'bilpoolni': 0, 'bilpoolnin': 0, 'bilpoolning': 0, 'bilpoolnings': 0, 'bilpoolningss': 0}
# {'ilpoolningss': 0, 'lpoolningss': 0, 'poolningss': 0, 'oolningss': 0, 'olningss': 0, 'lningss': 0, 'ningss': 0, 'ingss': 0, 'ngss': 0, 'gss': 0, 'ss': 38, 's': 656, '': 0}
# {'1': 27, '10': 20, '102': 0, '1024': 1}
# {'024': 1, '24': 1, '4': 12, '': 0}
# {'k': 1, 'kö': 0, 'kör': 5, 'körn': 0, 'körni': 0, 'körnin': 0, 'körning': 1, 'körninge': 0}
# {'örninge': 0, 'rninge': 0, 'ninge': 0, 'inge': 0, 'nge': 0, 'ge': 3, 'e': 489, '': 0}
# {'v': 2, 'va': 0, 'vat': 0, 'vatt': 0, 'vatte': 0, 'vatten': 12, 'vattent': 0, 'vattentv': 0}
# {'attentv': 0, 'ttentv': 0, 'tentv': 0, 'entv': 0, 'ntv': 0, 'tv': 0, 'v': 613, '': 0}
# {'r': 4, 're': 0, 'rev': 0, 'revi': 0, 'revis': 0, 'revisi': 0, 'revisio': 0, 'revision': 0, 'revisions': 0, 'revisionsu': 0, 'revisionsut': 0}
# {'evisionsut': 0, 'visionsut': 0, 'isionsut': 0, 'sionsut': 0, 'ionsut': 0, 'onsut': 0, 'nsut': 0, 'sut': 0, 'ut': 2, 't': 2270, '': 0}
# {'q': 1, 'qu': 0, 'quo': 0, 'quor': 0, 'quora': 48, 'quora-': 0, 'quora-f': 0, 'quora-fr': 0, 'quora-frå': 0, 'quora-fråg': 0}
# {'uora-fråg': 0, 'ora-fråg': 0, 'ra-fråg': 0, 'a-fråg': 0, '-fråg': 0, 'fråg': 0, 'råg': 0, 'åg': 6, 'g': 1974, '': 0}
# {'v': 2, 'vi': 150, 'vis': 0, 'vish': 0, 'vishn': 0, 'vishnu': 1}
# {'ishnu': 1, 'shnu': 1, 'hnu': 0, 'nu': 0, 'u': 22, '': 0}
# {'[': 0, '[m': 0, '[ma': 0, '[mat': 0, '[math': 0, '[math]': 1, '[math]b': 0, '[math]b^': 0, '[math]b^3': 0}
# {'math]b^3': 0, 'ath]b^3': 0, 'th]b^3': 0, 'h]b^3': 0, ']b^3': 0, 'b^3': 0, '^3': 0, '3': 10, '': 0}
# {'p': 0, 'pr': 1, 'pri': 0, 'pris': 3, 'prisö': 0}
# {'risö': 0, 'isö': 0, 'sö': 0, 'ö': 0, '': 0}
# ...
# {'asskommunikation?': 1, 'sskommunikation?': 0, 'skommunikation?': 1, 'kommunikation?': 1, 'ommunikation?': 1, 'mmunikation?': 0, 'munikation?': 1, 'unikation?': 0, 'nikation?': 0, 'ikation?': 0, 'kation?': 0, 'ation?': 2, 'tion?': 2, 'ion?': 3, 'on?': 2, 'n?': 112, '?': 4278, '': 0}
# {'l': 1, 'lä': 0, 'lär': 15, 'läro': 0, 'lärob': 0, 'lärobö': 0, 'läroböc': 0, 'läroböck': 0, 'läroböcke': 0, 'läroböcker': 0, 'läroböckern': 0, 'läroböckerna': 1}
# {'äroböckerna': 1, 'roböckerna': 0, 'oböckerna': 1, 'böckerna': 0, 'öckerna': 12, 'ckerna': 0, 'kerna': 2, 'erna': 121, 'rna': 44, 'na': 371, 'a': 2904, '': 0}
# {'p': 0, 'pe': 0, 'pep': 0, 'pept': 0, 'pepto': 1}
# {'epto': 0, 'pto': 0, 'to': 9, 'o': 72, '': 0}
# {'k': 1, 'kv': 0, 'kva': 0, 'kval': 0, 'kvali': 0, 'kvalif': 0, 'kvalifi': 0, 'kvalific': 0, 'kvalifice': 0, 'kvalificer': 0}
# {'valificer': 0, 'alificer': 0, 'lificer': 0, 'ificer': 0, 'ficer': 4, 'icer': 0, 'cer': 1, 'er': 769, 'r': 1785, '': 0}
# {'a': 3, 'am': 0, 'amm': 0, 'ammo': 0}
# {'mmo': 0, 'mo': 2, 'o': 72, '': 0}
# {'c': 2, 'ce': 0, 'cen': 0, 'cent': 0, 'centr': 0, 'centro': 0, 'centroi': 0}
# {'entroi': 0, 'ntroi': 0, 'troi': 0, 'roi': 0, 'oi': 1, 'i': 192, '': 0}
# {'m': 1, 'mi': 1, 'mik': 0, 'mikr': 0, 'mikro': 0, 'mikrof': 0, 'mikrofo': 0, 'mikrofok': 0, 'mikrofoku': 0, 'mikrofokus': 0, 'mikrofokuse': 0, 'mikrofokuser': 0, 'mikrofokusera': 0}
# {'ikrofokusera': 0, 'krofokusera': 0, 'rofokusera': 0, 'ofokusera': 0, 'fokusera': 0, 'okusera': 1, 'kusera': 0, 'usera': 0, 'sera': 2, 'era': 34, 'ra': 320, 'a': 2904, '': 0}
# {'u': 0, 'um': 0, 'umg': 0, 'umgä': 0, 'umgän': 0}
# {'mgän': 0, 'gän': 0, 'än': 21, 'n': 2639, '': 0}
# {'k': 1, 'ko': 0, 'kon': 1, 'kont': 0, 'kontr': 0, 'kontro': 0, 'kontrol': 0}
# {'ontrol': 0, 'ntrol': 0, 'trol': 0, 'rol': 1, 'ol': 5, 'l': 470, '': 0}
# {'t': 2, 'ta': 60, 'tan': 0, 'tand': 0, 'tandi': 0, 'tandim': 0, 'tandimp': 0, 'tandimpl': 0}
# {'andimpl': 0, 'ndimpl': 0, 'dimpl': 0, 'impl': 0, 'mpl': 0, 'pl': 2, 'l': 470, '': 0}
# {'b': 4, 'be': 1, 'bet': 0, 'bete': 1, 'betee': 0, 'beteen': 0, 'beteend': 0, 'beteende': 3, 'beteendem': 0, 'beteendemo': 0}
# {'eteendemo': 0, 'teendemo': 0, 'eendemo': 0, 'endemo': 0, 'ndemo': 0, 'demo': 0, 'emo': 0, 'mo': 2, 'o': 72, '': 0}
# {'r': 4, 're': 0, 'res': 0, 'reso': 0, 'reson': 0}
# {'eson': 0, 'son': 25, 'on': 16, 'n': 2639, '': 0}
# {'t': 2, 'ta': 60, 'tau': 0, 'taur': 0, 'tauru': 0, 'taurus': 1}
# {'aurus': 1, 'urus': 1, 'rus': 3, 'us': 8, 's': 656, '': 0}
# {'y': 0, 'yo': 1, 'you': 0, 'yout': 0, 'youtu': 0, 'youtub': 0, 'youtube': 13, 'youtube-': 0, 'youtube-v': 0, 'youtube-vi': 0, 'youtube-vid': 0, 'youtube-vide': 0}
# {'outube-vide': 0, 'utube-vide': 0, 'tube-vide': 0, 'ube-vide': 0, 'be-vide': 0, 'e-vide': 0, '-vide': 0, 'vide': 0, 'ide': 0, 'de': 196, 'e': 489, '': 0}
# {'a': 3, 'as': 0, 'asi': 0, 'asia': 0, 'asiat': 0, 'asiati': 0}
# {'siati': 0, 'iati': 0, 'ati': 1, 'ti': 6, 'i': 192, '': 0}
# {'o': 0, 'ob': 0, 'obl': 0, 'obli': 0, 'oblig': 0, 'obliga': 0, 'obligat': 0, 'obligato': 0}
# {'bligato': 0, 'ligato': 0, 'igato': 0, 'gato': 0, 'ato': 1, 'to': 9, 'o': 72, '': 0}
# {'o': 0, 'ot': 0, 'otr': 0, 'otro': 0, 'otrog': 0, 'otrogn': 0, 'otrogna': 2}
# {'trogna': 0, 'rogna': 0, 'ogna': 0, 'gna': 9, 'na': 371, 'a': 2904, '': 0}
# {'h': 0, 'he': 0, 'hem': 7, 'hemv': 0, 'hemvä': 0}
# {'emvä': 0, 'mvä': 0, 'vä': 0, 'ä': 0, '': 0}
# {'n': 3, 'ne': 0, 'ner': 65, 'nerf': 0, 'nerfö': 0, 'nerför': 1}
# {'erför': 1, 'rför': 0, 'för': 614, 'ör': 1300, 'r': 1785, '': 0}
# {'k': 1, 'kä': 0, 'kär': 18, 'kärn': 0, 'kärnf': 0, 'kärnfu': 0, 'kärnfus': 0, 'kärnfusi': 0}
# {'ärnfusi': 0, 'rnfusi': 0, 'nfusi': 0, 'fusi': 0, 'usi': 0, 'si': 1, 'i': 192, '': 0}
# {'c': 2, 'co': 0, 'co?': 1}
# {'o?': 13, '?': 4278, '': 0}
# {'i': 1572, 'in': 70, 'int': 0, 'intr': 0, 'intry': 0, 'intryc': 0}
# {'ntryc': 0, 'tryc': 0, 'ryc': 0, 'yc': 1, 'c': 25, '': 0}
# {'j': 0, 'ju': 0, 'jum': 0, 'jump': 0, 'jumpe': 0, 'jumper': 0, 'jumper.': 0}
# {'umper.': 0, 'mper.': 0, 'per.': 0, 'er.': 5, 'r.': 7, '.': 211, '': 0}
# {'2': 26, '2-': 0, '2-å': 0}
# {'-å': 0, 'å': 433, '': 0}
# {'i': 1572, 'ic': 0, 'ick': 0, 'icke': 9, 'icke-': 0, 'icke-k': 0, 'icke-ko': 0, 'icke-kon': 0, 'icke-kont': 0}
# {'cke-kont': 0, 'ke-kont': 0, 'e-kont': 0, '-kont': 0, 'kont': 0, 'ont': 0, 'nt': 18, 't': 2270, '': 0}
# {'s': 9, 'so': 0, 'sol': 0, 'solk': 0, 'solkr': 0, 'solkra': 0, 'solkraf': 0, 'solkraft': 0}
# {'olkraft': 0, 'lkraft': 0, 'kraft': 2, 'raft': 4, 'aft': 0, 'ft': 11, 't': 2270, '': 0}
# {'s': 9, 'st': 3, 'sta': 0, 'star': 4, 'stark': 4, 'starka': 1, 'starkar': 0, 'starkare': 1, 'starkare?': 2}
# {'tarkare?': 2, 'arkare?': 2, 'rkare?': 0, 'kare?': 2, 'are?': 32, 're?': 55, 'e?': 49, '?': 4278, '': 0}
# {'e': 11, 'ex': 2, 'exp': 1, 'expe': 0, 'exper': 0, 'experi': 0, 'experim': 0, 'experime': 0, 'experimen': 0, 'experiment': 4}
# {'xperiment': 4, 'periment': 4, 'eriment': 4, 'riment': 0, 'iment': 0, 'ment': 0, 'ent': 8, 'nt': 18, 't': 2270, '': 0}
# {'m': 1, 'my': 1, 'myn': 0, 'mynt': 3, 'mynt?': 1}
# {'ynt?': 1, 'nt?': 4, 't?': 227, '?': 4278, '': 0}
# {'n': 3, 'ni': 13, 'nic': 0, 'nice': 0}
# {'ice': 1, 'ce': 3, 'e': 489, '': 0}
# {'s': 9, 'sl': 0, 'sla': 0, 'slag': 2, 'slago': 0, 'slagor': 0, 'slagord': 1, 'slagord,': 1}
# {'lagord,': 1, 'agord,': 0, 'gord,': 0, 'ord,': 1, 'rd,': 0, 'd,': 2, ',': 410, '': 0}
# {'a': 3, 'an': 0, 'anv': 0, 'anvä': 0, 'använ': 0, 'använd': 0, 'använda': 73, 'användar': 0, 'användare': 8, 'användares': 1}
# {'nvändares': 1, 'vändares': 0, 'ändares': 0, 'ndares': 0, 'dares': 0, 'ares': 0, 'res': 2, 'es': 27, 's': 656, '': 0}
# {'t': 2, 'tr': 0, 'trä': 0, 'trän': 0, 'träni': 0, 'tränin': 0}
# {'ränin': 0, 'änin': 0, 'nin': 0, 'in': 434, 'n': 2639, '': 0}
# {'p': 0, 'pe': 0, 'pen': 0, 'penn': 0, 'penna': 1}
# {'enna': 0, 'nna': 50, 'na': 371, 'a': 2904, '': 0}
# {'h': 0, 'hu': 0, 'huv': 0, 'huvu': 0, 'huvud': 3, 'huvud-': 0, 'huvud-/': 0, 'huvud-/p': 0, 'huvud-/ph': 0, 'huvud-/phd': 0, 'huvud-/phd-': 0, 'huvud-/phd-f': 0, 'huvud-/phd-fä': 0}
# {'uvud-/phd-fä': 0, 'vud-/phd-fä': 0, 'ud-/phd-fä': 0, 'd-/phd-fä': 0, '-/phd-fä': 0, '/phd-fä': 0, 'phd-fä': 0, 'hd-fä': 0, 'd-fä': 0, '-fä': 0, 'fä': 0, 'ä': 0, '': 0}
# {'m': 1, 'må': 2, 'mål': 7, 'måle': 0}
# {'åle': 0, 'le': 16, 'e': 489, '': 0}
# {'a': 3, 'af': 0, 'aff': 0, 'affä': 0, 'affär': 1, 'affärs': 0, 'affärsh': 0, 'affärshu': 0}
# {'ffärshu': 0, 'färshu': 0, 'ärshu': 0, 'rshu': 0, 'shu': 0, 'hu': 0, 'u': 22, '': 0}
# {'s': 9, 'st': 3, 'stu': 0, 'stud': 0, 'stude': 0, 'studen': 0, 'student': 7, 'studentr': 0, 'studentra': 0, 'studentrab': 0, 'studentraba': 0, 'studentrabat': 0, 'studentrabatt': 0, 'studentrabatt?': 1}
# {'tudentrabatt?': 1, 'udentrabatt?': 1, 'dentrabatt?': 0, 'entrabatt?': 0, 'ntrabatt?': 0, 'trabatt?': 0, 'rabatt?': 1, 'abatt?': 0, 'batt?': 0, 'att?': 3, 'tt?': 21, 't?': 227, '?': 4278, '': 0}
# {'l': 1, 'li': 0, 'lit': 0, 'litt': 0, 'littl': 0, 'little': 0}
# {'ittle': 0, 'ttle': 1, 'tle': 0, 'le': 16, 'e': 489, '': 0}
# {'k': 1, 'ka': 0, 'kap': 0, 'kapt': 0, 'kapte': 0, 'kapten': 1, 'kaptens': 0, 'kaptensk': 0, 'kaptenska': 0}
# {'aptenska': 0, 'ptenska': 0, 'tenska': 0, 'enska': 0, 'nska': 34, 'ska': 68, 'ka': 266, 'a': 2904, '': 0}
# {'g': 4, 'ga': 0, 'gal': 0, 'gall': 0, 'gallb': 0, 'gallbl': 0, 'gallblå': 0}
# {'allblå': 0, 'llblå': 0, 'lblå': 0, 'blå': 1, 'lå': 7, 'å': 433, '': 0}
# {'w': 3, 'wh': 0, 'whi': 0, 'whis': 0, 'whisk': 0, 'whisky': 2}
# {'hisky': 2, 'isky': 0, 'sky': 0, 'ky': 1, 'y': 36, '': 0}
# {'u': 0, 'un': 0, 'und': 0, 'unde': 0, 'under': 87, 'underv': 0, 'undervi': 0, 'undervis': 0, 'undervisn': 0, 'undervisni': 0, 'undervisnin': 0, 'undervisning': 0, 'undervisnings': 0, 'undervisningss': 0, 'undervisningsst': 0}
# {'ndervisningsst': 0, 'dervisningsst': 0, 'ervisningsst': 0, 'rvisningsst': 0, 'visningsst': 0, 'isningsst': 0, 'sningsst': 0, 'ningsst': 0, 'ingsst': 0, 'ngsst': 0, 'gsst': 0, 'sst': 1, 'st': 34, 't': 2270, '': 0}
# {'m': 1, 'ma': 0, 'mar': 0, 'mark': 7, 'markn': 0, 'markna': 0, 'marknad': 1, 'marknads': 0, 'marknadsf': 0, 'marknadsfö': 0, 'marknadsför': 0, 'marknadsföri': 0, 'marknadsförin': 0, 'marknadsföring': 3, 'marknadsförings': 0, 'marknadsföringsp': 0, 'marknadsföringspr': 0, 'marknadsföringspre': 0}
# {'arknadsföringspre': 0, 'rknadsföringspre': 0, 'knadsföringspre': 0, 'nadsföringspre': 0, 'adsföringspre': 0, 'dsföringspre': 0, 'sföringspre': 0, 'föringspre': 0, 'öringspre': 0, 'ringspre': 0, 'ingspre': 0, 'ngspre': 0, 'gspre': 0, 'spre': 0, 'pre': 0, 're': 112, 'e': 489, '': 0}
# {'k': 1, 'kv': 0, 'kva': 0, 'kvan': 0, 'kvant': 0, 'kvantt': 0, 'kvantte': 0, 'kvantteo': 0, 'kvantteor': 0, 'kvantteori': 0}
# {'vantteori': 0, 'antteori': 0, 'ntteori': 0, 'tteori': 0, 'teori': 0, 'eori': 1, 'ori': 1, 'ri': 4, 'i': 192, '': 0}
# {'b': 4, 'ba': 1, 'ban': 0, 'bang': 4, 'banga': 0, 'bangal': 0}
# {'angal': 0, 'ngal': 1, 'gal': 0, 'al': 33, 'l': 470, '': 0}
# {'k': 1, 'kö': 0, 'kör': 5, 'körd': 0, 'körde': 1}
# {'örde': 3, 'rde': 5, 'de': 196, 'e': 489, '': 0}
# {'b': 4, 'be': 1, 'beg': 0, 'begr': 0, 'begrä': 0, 'begrän': 0, 'begräns': 0, 'begränsn': 0}
# {'egränsn': 0, 'gränsn': 0, 'ränsn': 0, 'änsn': 0, 'nsn': 0, 'sn': 0, 'n': 2639, '': 0}
# {'a': 3, 'an': 0, 'ana': 0, 'anal': 0, 'analy': 0, 'analys': 1, 'analyse': 0}
# {'nalyse': 0, 'alyse': 0, 'lyse': 0, 'yse': 0, 'se': 10, 'e': 489, '': 0}
# {'f': 2, 'fö': 0, 'för': 1109, 'förs': 0, 'först': 1, 'förstö': 0, 'förstör': 1, 'förstöra': 0}
# {'örstöra': 0, 'rstöra': 0, 'störa': 0, 'töra': 0, 'öra': 210, 'ra': 320, 'a': 2904, '': 0}
# {'h': 0, 'he': 0, 'hem': 7, 'heml': 0, 'hemli': 0, 'hemlig': 0, 'hemligh': 0, 'hemlighe': 0, 'hemlighet': 1, 'hemlighets': 0, 'hemlighetsf': 0, 'hemlighetsfu': 0, 'hemlighetsful': 0, 'hemlighetsfull': 1}
# {'emlighetsfull': 0, 'mlighetsfull': 0, 'lighetsfull': 1, 'ighetsfull': 0, 'ghetsfull': 0, 'hetsfull': 0, 'etsfull': 0, 'tsfull': 0, 'sfull': 1, 'full': 3, 'ull': 1, 'll': 99, 'l': 470, '': 0}
# {'s': 9, 'si': 0, 'sin': 62, 'sina': 38}
# {'ina': 123, 'na': 371, 'a': 2904, '': 0}
# {'c': 2, 'ch': 0, 'cha': 0, 'cham': 0}
# {'ham': 1, 'am': 14, 'm': 67, '': 0}
# {'"': 2, '"g': 0, '"ge': 0}
# {'ge': 3, 'e': 489, '': 0}
# {'k': 1, 'ky': 1, 'kyc': 0, 'kyc-': 0, 'kyc-k': 0, 'kyc-ko': 0, 'kyc-kom': 0, 'kyc-komp': 0, 'kyc-kompa': 0, 'kyc-kompat': 0, 'kyc-kompati': 0, 'kyc-kompatib': 0, 'kyc-kompatibe': 0, 'kyc-kompatibel': 0, 'kyc-kompatibelt': 1}
# {'yc-kompatibelt': 1, 'c-kompatibelt': 1, '-kompatibelt': 0, 'kompatibelt': 0, 'ompatibelt': 0, 'mpatibelt': 0, 'patibelt': 0, 'atibelt': 0, 'tibelt': 0, 'ibelt': 0, 'belt': 0, 'elt': 0, 'lt': 12, 't': 2270, '': 0}
# {'d': 0, 'dc': 0, 'dc?': 1}
# {'c?': 9, '?': 4278, '': 0}
# {'c': 2, 'cr': 0, 'cry': 0, 'cryp': 0, 'crypt': 0}
# {'rypt': 0, 'ypt': 0, 'pt': 2, 't': 2270, '': 0}
# {'s': 9, 'sl': 0, 'slä': 0, 'släp': 0, 'släpp': 0, 'släppa': 4}
# {'läppa': 4, 'äppa': 0, 'ppa': 4, 'pa': 16, 'a': 2904, '': 0}
# {'g': 4, 'gm': 0, 'gmo': 0, 'gmo-': 0, 'gmo-p': 0, 'gmo-pr': 0, 'gmo-pro': 0}
# {'mo-pro': 0, 'o-pro': 0, '-pro': 0, 'pro': 0, 'ro': 7, 'o': 72, '': 0}
# {'f': 2, 'fa': 0, 'fas': 2, 'fast': 5, 'fasti': 0, 'fastig': 0, 'fastigh': 0, 'fastighe': 0, 'fastighet': 0, 'fastighets': 0, 'fastighetst': 0, 'fastighetstr': 0, 'fastighetstra': 0, 'fastighetstran': 0, 'fastighetstrans': 0, 'fastighetstransa': 0, 'fastighetstransak': 0, 'fastighetstransakt': 0, 'fastighetstransakti': 0, 'fastighetstransaktio': 0, 'fastighetstransaktion': 0}
# {'astighetstransaktion': 0, 'stighetstransaktion': 0, 'tighetstransaktion': 0, 'ighetstransaktion': 0, 'ghetstransaktion': 0, 'hetstransaktion': 0, 'etstransaktion': 0, 'tstransaktion': 0, 'stransaktion': 0, 'transaktion': 0, 'ransaktion': 0, 'ansaktion': 0, 'nsaktion': 0, 'saktion': 0, 'aktion': 0, 'ktion': 1, 'tion': 4, 'ion': 4, 'on': 16, 'n': 2639, '': 0}
# {'g': 4, 'gå': 83, 'gån': 0, 'gång': 9, 'gånge': 0, 'gånger': 13, 'gånger?': 3}
# {'ånger?': 3, 'nger?': 4, 'ger?': 2, 'er?': 118, 'r?': 74, '?': 4278, '': 0}
# {'k': 1, 'ka': 0, 'kap': 0, 'kapi': 0, 'kapit': 0, 'kapita': 0, 'kapital': 0, 'kapitalk': 0, 'kapitalkr': 0, 'kapitalkra': 0}
# {'apitalkra': 0, 'pitalkra': 0, 'italkra': 0, 'talkra': 0, 'alkra': 0, 'lkra': 0, 'kra': 0, 'ra': 320, 'a': 2904, '': 0}
# {'b': 4, 'br': 1, 'brä': 0, 'bräd': 0, 'brädo': 0, 'brädor': 1, 'brädor)': 0}
# {'rädor)': 0, 'ädor)': 0, 'dor)': 0, 'or)': 0, 'r)': 0, ')': 38, '': 0}
# {'3': 26, '38': 0}
# {'8': 4, '': 0}
# {'l': 1, 'lå': 0, 'lån': 3, 'lång': 28, 'långä': 0}
# {'ångä': 0, 'ngä': 0, 'gä': 0, 'ä': 0, '': 0}
# {'h': 0, 'he': 0, 'hel': 2, 'heli': 0, 'helik': 0, 'heliko': 0, 'helikop': 0, 'helikopt': 0, 'helikopte': 0, 'helikopter': 1, 'helikoptert': 0, 'helikoptertj': 0, 'helikoptertjä': 0, 'helikoptertjän': 0}
# {'elikoptertjän': 0, 'likoptertjän': 0, 'ikoptertjän': 0, 'koptertjän': 0, 'optertjän': 0, 'ptertjän': 0, 'tertjän': 0, 'ertjän': 0, 'rtjän': 0, 'tjän': 0, 'jän': 0, 'än': 21, 'n': 2639, '': 0}
# {'c': 2, 'c-': 0, 'c-v': 0, 'c-vi': 0, 'c-vit': 0, 'c-vita': 0}
# {'-vita': 0, 'vita': 0, 'ita': 17, 'ta': 134, 'a': 2904, '': 0}
# {'k': 1, 'ko': 0, 'ko-': 0, 'ko-u': 0, 'ko-ur': 0, 'ko-uri': 0, 'ko-urin': 1}
# {'o-urin': 1, '-urin': 0, 'urin': 0, 'rin': 0, 'in': 434, 'n': 2639, '': 0}
# {'h': 0, 'ho': 0, 'hon': 37, 'hona': 0}
# {'ona': 1, 'na': 371, 'a': 2904, '': 0}
# {'n': 3, 'ne': 0, 'ned': 1, 'neds': 0, 'nedsk': 0, 'nedskä': 0, 'nedskär': 0, 'nedskärn': 0, 'nedskärni': 0, 'nedskärnin': 0, 'nedskärning': 0, 'nedskärninge': 0, 'nedskärningen': 2}
# {'edskärningen': 2, 'dskärningen': 0, 'skärningen': 2, 'kärningen': 0, 'ärningen': 0, 'rningen': 0, 'ningen': 8, 'ingen': 15, 'ngen': 25, 'gen': 58, 'en': 811, 'n': 2639, '': 0}
# {'s': 9, 'se': 40, 'sex': 20, 'sexs': 0, 'sexsi': 0, 'sexsid': 0}
# {'exsid': 0, 'xsid': 0, 'sid': 0, 'id': 118, 'd': 158, '': 0}
# {'i': 1572, 'il': 0, 'ill': 0, 'ille': 0, 'illeg': 0, 'illega': 0, 'illegal': 0}
# {'llegal': 0, 'legal': 0, 'egal': 0, 'gal': 0, 'al': 33, 'l': 470, '': 0}
# {'m': 1, 'ma': 0, 'mat': 8, 'matt': 0, 'matte': 2, 'matter': 0}
# {'atter': 2, 'tter': 7, 'ter': 21, 'er': 769, 'r': 1785, '': 0}
# {'a': 3, 'as': 0, 'asp': 0, 'aspe': 0}
# {'spe': 0, 'pe': 1, 'e': 489, '': 0}
# {'t': 2, 'te': 10, 'tek': 0, 'tekn': 0, 'tekni': 0, 'teknik': 4, 'teknikr': 0, 'teknikre': 0, 'teknikrek': 0, 'teknikrekr': 0, 'teknikrekry': 0, 'teknikrekryt': 0, 'teknikrekryte': 0, 'teknikrekryter': 0}
# {'eknikrekryter': 0, 'knikrekryter': 0, 'nikrekryter': 0, 'ikrekryter': 0, 'krekryter': 0, 'rekryter': 0, 'ekryter': 0, 'kryter': 0, 'ryter': 7, 'yter': 8, 'ter': 21, 'er': 769, 'r': 1785, '': 0}
# {'v': 2, 'vå': 0, 'vål': 0, 'våld': 1, 'våldt': 0, 'våldta': 0, 'våldtag': 0}
# {'åldtag': 0, 'ldtag': 0, 'dtag': 0, 'tag': 28, 'ag': 14, 'g': 1974, '': 0}
# {'m': 1, 'mi': 1, 'mig': 176, 'mig.': 6, 'mig.l': 0}
# {'ig.l': 0, 'g.l': 0, '.l': 0, 'l': 470, '': 0}
# {'s': 9, 'sa': 7, 'sak': 3, 'sake': 0, 'saker': 49, 'sakern': 0, 'sakerna': 2, 'sakerna,': 1}
# {'akerna,': 1, 'kerna,': 1, 'erna,': 1, 'rna,': 0, 'na,': 2, 'a,': 16, ',': 410, '': 0}
# {'g': 4, 'gp': 0, 'gpu': 1, 'gpu-': 0, 'gpu-l': 0, 'gpu-lö': 0, 'gpu-lös': 0, 'gpu-lösn': 0, 'gpu-lösni': 0, 'gpu-lösnin': 0, 'gpu-lösning': 0, 'gpu-lösninga': 0, 'gpu-lösningar': 0, 'gpu-lösningarn': 0, 'gpu-lösningarna': 0}
# {'pu-lösningarna': 0, 'u-lösningarna': 0, '-lösningarna': 0, 'lösningarna': 0, 'ösningarna': 0, 'sningarna': 0, 'ningarna': 1, 'ingarna': 1, 'ngarna': 1, 'garna': 2, 'arna': 66, 'rna': 44, 'na': 371, 'a': 2904, '': 0}
# {'p': 0, 'pe': 0, 'pen': 0, 'pens': 0, 'pensi': 0, 'pensio': 0, 'pension': 1, 'pensions': 0, 'pensionss': 0, 'pensionssy': 0, 'pensionssys': 0, 'pensionssyst': 0}
# {'ensionssyst': 0, 'nsionssyst': 0, 'sionssyst': 0, 'ionssyst': 0, 'onssyst': 0, 'nssyst': 0, 'ssyst': 0, 'syst': 0, 'yst': 1, 'st': 34, 't': 2270, '': 0}
# {'t': 2, 'tu': 0, 'tu,': 1}
# {'u,': 3, ',': 410, '': 0}
# {'"': 2, '""': 13, '""a': 0, '""ac': 0, '""acc': 0, '""acce': 0, '""accep': 0, '""accept': 1, '""accepte': 0}
# {'"accepte': 0, 'accepte': 0, 'ccepte': 0, 'cepte': 0, 'epte': 0, 'pte': 1, 'te': 317, 'e': 489, '': 0}
# {'p': 0, 'pl': 1, 'plå': 0, 'plån': 0, 'plånb': 0, 'plånbö': 0, 'plånböc': 0, 'plånböck': 0, 'plånböcke': 0}
# {'lånböcke': 0, 'ånböcke': 0, 'nböcke': 0, 'böcke': 0, 'öcke': 0, 'cke': 9, 'ke': 4, 'e': 489, '': 0}

# %% [markdown]
# *Character-based tokenizer for transformer*

# %%
class Tokenizer():
    def __init__(self, morph: Morph):
        text = ' '
        for word in morph.vocab:
            text += word
        self.padding_token = '<PAD>'
        self.chars = [self.padding_token] + sorted(list(set(text)))
        self.i2w = { i: char for i, char in enumerate(self.chars) }
        self.w2i = { char: i for i, char in enumerate(self.chars) }

        self.longest_word = max(list(morph.vocab), key=len)

    def encode(self, string):
        encoding = [self.w2i[c] for c in string]
        padding = [self.w2i[self.padding_token] for _ in range(len(self.longest_word) - len(string))]
        mask = [1 for _ in encoding] + [0 for _ in padding]
        return encoding + padding, mask

    def decode(self, idx):
        return ''.join([self.i2w[c] for c in idx if self.i2w[c] != self.padding_token])

# %% [markdown]
# *Transformer with one bidirectional-attention block*

# %%
class Transformer(nn.Module):

    def __init__(self, input_dim, embed_dim, max_len):
        super(Transformer, self).__init__()
        self.embed_dim = embed_dim
        self.max_len = max_len

        self.embed = nn.Embedding(input_dim, embed_dim)
        self.keys = nn.Linear(embed_dim, embed_dim, bias=False)
        self.queries = nn.Linear(embed_dim, embed_dim, bias=False)
        self.values = nn.Linear(embed_dim, embed_dim, bias=False)

        self.output = nn.Linear(embed_dim*max_len, max_len)


    def forward(self, x, mask):

        x = self.embed(x)

        q = self.queries(x)
        k = self.keys(x)
        v = self.values(x)

        a = self.attention(q, k, v, mask)

        out = F.softmax(self.output(a.view(-1, self.max_len * self.embed_dim)), dim=1)

        return out

    def attention(self, q, k, v, mask):

        wei = q @ k.transpose(-2, -1)

        wei = wei.masked_fill(mask[:, :, None] == 0, float('-inf'))
        score = F.softmax(wei, dim=1)

        return score @ v

    def get_pseudo_labels(self, x):
        return

# %% [markdown]
# *Dataset classes for training supervised and semi-supervised*

# %%
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
ratio = 10

class LabeledSet(Dataset):

    def __init__(self, data: Dict, tok: Tokenizer):
        self.tok = tok

        self.words = list(data.keys())
        self.labels = list(data.values())

    def __getitem__(self, idx):
        word = self.words[idx]
        ending = self.labels[idx]

        encoded_word, mask = self.tok.encode(word)
        data, mask = torch.tensor(encoded_word, dtype=torch.int32, device=device), torch.tensor(mask, dtype=torch.int32, device=device)
        label = torch.tensor(len(word) - len(ending), device=device, dtype=torch.int64)

        return data, mask, label

    def __len__(self):
        return len(self.words)

class UnLabaledSet(Dataset):

    def __init__(self, data: Dict, tok: Tokenizer, num_batches: int):
        self.tok = tok

        self.words = list(data.keys())[:batch_size*ratio*batch_size]

    def __getitem__(self, idx):

        word = self.words[idx]
        encoded_word, mask = self.tok.encode(word)
        data, mask = torch.tensor(encoded_word, dtype=torch.int32, device=device), torch.tensor(mask, dtype=torch.int32, device=device)

        return data, mask

    def __len__(self):
        return len(self.words)


batch_size = 4

t = Tokenizer(m)

unlabeled_data = dict(m.counts)

L = LabeledSet(labeled_data, t)

num_batches = len(L) // batch_size

UL = UnLabaledSet(unlabeled_data, t, num_batches)

unlbd_dl = DataLoader(UL, shuffle=True, batch_size=batch_size*ratio)
lbd_dl = DataLoader(L, shuffle=True, batch_size=batch_size)

# %% [markdown]
# SEMI-SUPERVISED TRAINING, skip unless you want to train from scratch

# %%
from torch.optim import AdamW
from tqdm.auto import tqdm

def alpha(t):
    T1 = 15
    T2 = 95
    alpha_f = 3

    if t < T1:
        return 0
    elif T1 <= t < T2:
        return ((t - T1) / (T2 - T1)) * alpha_f
    else:
        return alpha_f

model = Transformer(len(t.chars), 32, len(t.longest_word))
model = model.to(device)
opt = AdamW(model.parameters(), lr=0.001)
epochs = 100
crit = nn.CrossEntropyLoss()
bar = tqdm(range(epochs))

losses = []
iter_dl = iter(unlbd_dl)

for epoch in range(epochs):
  total_loss = 0
  total_unlbd = 0
  total_lbd = 0

  for data, mask, labels in lbd_dl:

      pred = model(data, mask)

      lbd_loss = F.cross_entropy(pred, labels) / pred.shape[0]

      for data, mask in unlbd_dl:
          break

      pred = model(data, mask)

      pseudo_labels = torch.argmax(pred, dim=1).detach()

      unlbd_loss = F.cross_entropy(pred, pseudo_labels) / pred.shape[0]

      loss = lbd_loss + (alpha(epoch) * unlbd_loss)

      loss.backward()
      opt.step()
      opt.zero_grad()

      total_loss += loss.item()
      total_lbd += lbd_loss.item()
      total_unlbd += unlbd_loss.item()

  bar.set_description(f"Alpha = {round(alpha(epoch), 3)} Unlab = {round(total_unlbd)} Lab = {round(total_lbd)} Loss: {round(total_loss)}")
  bar.update()
  losses.append(total_loss)

  semi_model = model
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# *Loading pre-trained model, skip if training model from scratch*

# %%
semi_model = Transformer(len(t.chars), 32, len(t.longest_word))
semi_model.to(device)
semi_model.load_state_dict(torch.load('/content/gdrive/MyDrive/semi_model.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# *Evaluation of semi-supervised model*

# %%
words = ["barnen", 'stabilt', 'ditt', 'sked?', 'badkar', 'spelad', 'skedar', 'spelat']
masks = torch.zeros(8, len(t.longest_word), dtype=torch.int64).to(device)
tens = torch.zeros(8, len(t.longest_word), dtype=torch.int64).to(device)

for i, word in enumerate(words):
  en, mask = t.encode(word)
  ten = torch.tensor(en, device=device, dtype=torch.int64)
  mask = torch.tensor(mask, device=device, dtype=torch.int64)
  tens[i, :] = ten
  masks[i, :] = mask

preds = torch.argmax(semi_model(tens, masks), dim=1).cpu().detach().numpy()
print(preds)
for i, word in enumerate(words):
  print(word[:preds[i]] + '-' + word[preds[i]:])
# Out:
# [4 6 3 4 5 4 5 5]
# barn-en
# stabil-t
# dit-t
# sked-?
# badka-r
# spel-ad
# skeda-r
# spela-t

# %% [markdown]
# SUPERVISED TRAINING, skip unless you want to train from scratch

# %%
from torch.optim import AdamW
from tqdm.auto import tqdm


model = Transformer(len(t.chars), 32, len(t.longest_word))
model = model.to(device)
opt = AdamW(model.parameters(), lr=0.0005)
epochs = 100
crit = nn.CrossEntropyLoss()
bar = tqdm(range(epochs))

losses = []
for epoch in range(epochs):
  total_loss = 0
  for data, mask, labels in lbd_dl:

      pred = model(data, mask)

      lbd_loss = F.cross_entropy(pred, labels)

      loss = lbd_loss

      loss.backward()
      opt.step()
      opt.zero_grad()
      total_loss += loss.item()

  bar.set_description(f"Loss: {round(total_loss, 3)}")
  bar.update()
  losses.append(total_loss)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# *Pre-trained model, skip if training from scratch*

# %%
model = Transformer(len(t.chars), 32, len(t.longest_word))
model.to(device)
model.load_state_dict(torch.load('/content/gdrive/MyDrive/model.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# *Evaluation of supervised model*

# %%
words = ["barnen", 'stabilt', 'ditt', 'sked?', 'badkar', 'spelad', 'skedar', 'spelat']
masks = torch.zeros(8, len(t.longest_word), dtype=torch.int64).to(device)
tens = torch.zeros(8, len(t.longest_word), dtype=torch.int64).to(device)

for i, word in enumerate(words):
  en, mask = t.encode(word)
  ten = torch.tensor(en, device=device, dtype=torch.int64)
  mask = torch.tensor(mask, device=device, dtype=torch.int64)
  tens[i, :] = ten
  masks[i, :] = mask

preds = torch.argmax(model(tens, masks), dim=1).cpu().detach().numpy()
print(preds)
for i, word in enumerate(words):
  print(word[:preds[i]] + '-' + word[preds[i]:])
# Out:
# [4 6 4 4 5 6 4 4]
# barn-en
# stabil-t
# ditt-
# sked-?
# badka-r
# spelad-
# sked-ar
# spel-at

# %%
model
# Out:
# Transformer(
#   (embed): Embedding(81, 32)
#   (keys): Linear(in_features=32, out_features=32, bias=False)
#   (queries): Linear(in_features=32, out_features=32, bias=False)
#   (values): Linear(in_features=32, out_features=32, bias=False)
#   (output): Linear(in_features=1248, out_features=39, bias=True)
# )

# %%
semi_model
# Out:
# Transformer(
#   (embed): Embedding(81, 32)
#   (keys): Linear(in_features=32, out_features=32, bias=False)
#   (queries): Linear(in_features=32, out_features=32, bias=False)
#   (values): Linear(in_features=32, out_features=32, bias=False)
#   (output): Linear(in_features=1248, out_features=39, bias=True)
# )

# %%
m = Transformer()
